# %%
# !pip install fasttext
# !pip install gensim

# %%
import gensim 
import logging

# %% [markdown]
# * INTERVIEW: NPR Media Dialog Transcripts
#
# https://www.kaggle.com/datasets/shuyangli94/interview-npr-media-dialog-transcripts/
#
# * Data consists of 140K+ NPR radio transcripts (from npr.org) covering 20 years of NPR programs, comprising the transcriptions of 10K+ hours of audio. It is introduced and used in the following papers (please cite them if you use this dataset!)

# %%
with open("./media/npr_1000_utterances.csv", 'r') as f:
    i = 0 
    for i,line in enumerate (f):
        print(line)
        if i ==3:
            break
        i += 1
# Out:
# episode,episode_order,speaker,utterance
#
# 57264,9,"Ms. LOREN MOONEY (Editor-in-Chief, Bicycling Magazine)","It's a 2,200-mile race. To give some sense of perspective, that's roughly the distance between Washington, D.C. and Las Vegas. They do it over the course of three weeks at very fast speeds. But incredibly, oftentimes the distance between first and second is somewhere between and one and three minutes."
#
# 57264,10,"Ms. LOREN MOONEY (Editor-in-Chief, Bicycling Magazine)","So for a top competitor like Lance to try to make up that much time -he's now 13 minutes, 26 seconds behind the current race leader, Cadel Evans of Australia. And even Lance said yesterday that for him, the -any chance of winning the tour has gone out the window. He still does have a teammate on his team, RadioShack team, American Levi Leipheimer currently in eighth place, two minutes, 14 seconds back. And Lance is going to do what he can to help Leipheimer do well."
#
# 57264,11,"NEAL CONAN, host","So in every team, presumably there's one star, one equivalent to Lance Armstrong and the other team - the rest of the teammates project him, do what they can to help him succeed?"

# %%
input_file
# Out:
# './media/npr_1000_utterances.csv'

# %%
import csv
reader = csv.reader(open("./media/npr_1000_utterances.csv"), delimiter=',', quotechar='"')
for row in reader:
    print(row)
    break
# Out:
# ['episode', 'episode_order', 'speaker', 'utterance']

# %%
def read_input(input_file):
    utterances = []
    with open(input_file, newline='', encoding='utf-8') as csvfile:
        reader = csv.reader(csvfile, delimiter=',', quotechar='"')
        next(reader, None)
        for row in reader:
            text = row[-1]  
            yield gensim.utils.simple_preprocess(text)  # Yield the preprocessed text

utterances = list(read_input("./media/npr_1000_utterances.csv"))

# %%
utterances
# Out:
# [['it',
#   'mile',
#   'race',
#   'to',
#   'give',
#   'some',
#   'sense',
#   'of',
#   'perspective',
#   'that',
#   'roughly',
#   'the',
#   'distance',
#   'between',
#   'washington',
#   'and',
#   'las',
#   'vegas',
#   'they',
#   'do',
#   'it',
#   'over',
#   'the',
#   'course',
#   'of',
#   'three',
#   'weeks',
#   'at',
#   'very',
#   'fast',
#   'speeds',
#   'but',
#   'incredibly',
#   'oftentimes',
#   'the',
#   'distance',
#   'between',
#   'first',
#   'and',
#   'second',
#   'is',
#   'somewhere',
#   'between',
#   'and',
#   'one',
#   'and',
#   'three',
#   'minutes'],
#  ['so',
#   'for',
#   'top',
#   'competitor',
#   'like',
#   'lance',
#   'to',
#   'try',
#   'to',
#   'make',
#   'up',
#   'that',
#   'much',
#   'time',
#   'he',
#   'now',
#   'minutes',
#   'seconds',
#   'behind',
#   'the',
#   'current',
#   'race',
#   'leader',
#   'cadel',
#   'evans',
#   'of',
#   'australia',
#   'and',
#   'even',
#   'lance',
#   'said',
#   'yesterday',
#   'that',
#   'for',
#   'him',
#   'the',
#   'any',
#   'chance',
#   'of',
#   'winning',
#   'the',
#   'tour',
#   'has',
#   'gone',
#   'out',
#   'the',
#   'window',
#   'he',
#   'still',
#   'does',
#   'have',
#   'teammate',
#   'on',
#   'his',
#   'team',
#   'radioshack',
#   'team',
#   'american',
#   'levi',
#   'leipheimer',
#   'currently',
#   'in',
#   'eighth',
#   'place',
#   'two',
#   'minutes',
#   'seconds',
#   'back',
#   'and',
#   'lance',
#   'is',
#   'going',
#   'to',
#   'do',
#   'what',
#   'he',
#   'can',
#   'to',
#   'help',
#   'leipheimer',
#   'do',
#   'well'],
#  ['so',
#   'in',
#   'every',
#   'team',
#   'presumably',
#   'there',
#   'one',
#   'star',
#   'one',
#   'equivalent',
#   'to',
#   'lance',
#   'armstrong',
#   'and',
#   'the',
#   'other',
#   'team',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'teammates',
#   'project',
#   'him',
#   'do',
#   'what',
#   'they',
#   'can',
#   'to',
#   'help',
#   'him',
#   'succeed'],
#  ['that',
#   'right',
#   'each',
#   'team',
#   'has',
#   'nine',
#   'riders',
#   'and',
#   'what',
#   'you',
#   'have',
#   'is',
#   'basically',
#   'the',
#   'team',
#   'leader',
#   'sort',
#   'of',
#   'your',
#   'queen',
#   'bee',
#   'and',
#   'then',
#   'eight',
#   'worker',
#   'bees',
#   'working',
#   'to',
#   'keep',
#   'that',
#   'queen',
#   'safe',
#   'and',
#   'happy',
#   'for',
#   'when',
#   'the',
#   'decisive',
#   'moments',
#   'of',
#   'the',
#   'race',
#   'come',
#   'in',
#   'cycling',
#   'lot',
#   'of',
#   'the',
#   'energy',
#   'goes',
#   'toward',
#   'actually',
#   'battling',
#   'wind',
#   'resistance',
#   'so',
#   'if',
#   'you',
#   're',
#   'riding',
#   'behind',
#   'another',
#   'rider',
#   'you',
#   'can',
#   'be',
#   'using',
#   'up',
#   'to',
#   'percent',
#   'less',
#   'energy',
#   'because',
#   'you',
#   're',
#   'in',
#   'that',
#   'slipstream',
#   'of',
#   'the',
#   'rider',
#   'who',
#   'battling',
#   'the',
#   'wind',
#   'so',
#   'team',
#   'riders',
#   'will',
#   'ride',
#   'on',
#   'the',
#   'front',
#   'protect',
#   'their',
#   'leader',
#   'you',
#   'll',
#   'often',
#   'see',
#   'team',
#   'member',
#   'drift',
#   'back',
#   'to',
#   'the',
#   'team',
#   'car',
#   'to',
#   'fetch',
#   'water',
#   'bottles',
#   'to',
#   'keep',
#   'their',
#   'leader',
#   'well',
#   'hydrated'],
#  ['so',
#   'slipstream',
#   'this',
#   'is',
#   'like',
#   'drafting',
#   'in',
#   'car',
#   'racing',
#   'right'],
#  ['that', 'exactly', 'right'],
#  ['and',
#   'so',
#   'the',
#   'guy',
#   'who',
#   'in',
#   'back',
#   'has',
#   'an',
#   'easier',
#   'time',
#   'and',
#   'even',
#   'when',
#   'there',
#   'are',
#   'people',
#   'in',
#   'front',
#   'on',
#   'breakaway',
#   'for',
#   'example',
#   'who',
#   'are',
#   'from',
#   'different',
#   'teams',
#   'three',
#   'or',
#   'four',
#   'riders',
#   'you',
#   'will',
#   'see',
#   'them',
#   'switch',
#   'back',
#   'and',
#   'forth',
#   'rather',
#   'congenially',
#   'so',
#   'the',
#   'same',
#   'person',
#   'isn',
#   'in',
#   'front',
#   'all',
#   'the',
#   'time'],
#  ['that',
#   'right',
#   'there',
#   'lot',
#   'of',
#   'deal',
#   'making',
#   'that',
#   'can',
#   'go',
#   'on',
#   'in',
#   'those',
#   'breakaways',
#   'and',
#   'oftentimes',
#   'they',
#   'll',
#   'share',
#   'the',
#   'work',
#   'until',
#   'time',
#   'when',
#   'they',
#   've',
#   'determined',
#   'it',
#   'every',
#   'man',
#   'for',
#   'himself',
#   'but',
#   'up',
#   'until',
#   'then',
#   'they',
#   'form',
#   'sort',
#   'of',
#   'de',
#   'facto',
#   'team',
#   'and',
#   'then',
#   'sometimes',
#   'you',
#   'can',
#   'see',
#   'they',
#   've',
#   'actually',
#   'decided',
#   'who',
#   'might',
#   'be',
#   'able',
#   'to',
#   'win',
#   'the',
#   'stage',
#   'that',
#   'day',
#   'and',
#   'these',
#   'wagers',
#   'can',
#   'be',
#   'for',
#   'anything',
#   'for',
#   'future',
#   'favors',
#   'for',
#   'money',
#   'for',
#   'other',
#   'things',
#   'that',
#   'they',
#   'determine',
#   'are',
#   'valuable'],
#  ['we',
#   're',
#   'talking',
#   'with',
#   'loren',
#   'mooney',
#   'the',
#   'editor',
#   'in',
#   'chief',
#   'of',
#   'bicycling',
#   'magazine',
#   'she',
#   'at',
#   'our',
#   'bureau',
#   'in',
#   'new',
#   'york',
#   'why',
#   'do',
#   'you',
#   'watch',
#   'the',
#   'tour',
#   'de',
#   'france',
#   'so',
#   'we',
#   'want',
#   'to',
#   'hear',
#   'from',
#   'our',
#   'bicycling',
#   'audience',
#   'today',
#   'email',
#   'us',
#   'talk',
#   'npr',
#   'org',
#   'and',
#   'we',
#   'll',
#   'start',
#   'with',
#   'john',
#   'ph',
#   'john',
#   'with',
#   'us',
#   'from',
#   'san',
#   'francisco'],
#  ['hello'],
#  ['hi', 'john'],
#  ['yeah',
#   'the',
#   'bicycle',
#   'or',
#   'the',
#   'tour',
#   'de',
#   'france',
#   'for',
#   'me',
#   'is',
#   'just',
#   'kind',
#   'of',
#   'the',
#   'ultimate',
#   'extension',
#   'of',
#   'what',
#   'can',
#   'be',
#   'done',
#   'with',
#   'the',
#   'bicycle',
#   'the',
#   'bicycle',
#   'is',
#   'the',
#   'most',
#   'efficient',
#   'form',
#   'of',
#   'transportation',
#   'as',
#   'far',
#   'as',
#   'energy',
#   'spent',
#   'for',
#   'single',
#   'human',
#   'being',
#   'and',
#   'to',
#   'me',
#   'the',
#   'tour',
#   'is',
#   'just',
#   'takes',
#   'it',
#   'to',
#   'the',
#   'utmost',
#   'what',
#   'can',
#   'or',
#   'what',
#   'are',
#   'the',
#   'outer',
#   'limits',
#   'of',
#   'what',
#   'one',
#   'man',
#   'can',
#   'do',
#   'with',
#   'this',
#   'machine',
#   'it',
#   'kind',
#   'of',
#   'puts',
#   'it',
#   'all',
#   'at',
#   'the',
#   'very',
#   'top',
#   'limit',
#   'of',
#   'what',
#   'possible'],
#  ['the',
#   'ultimate',
#   'expression',
#   'the',
#   'training',
#   'that',
#   'you',
#   'have',
#   'to',
#   'do',
#   'for',
#   'this',
#   'john',
#   'though',
#   'is',
#   'pretty',
#   'ferocious'],
#  ['that',
#   'also',
#   'but',
#   'if',
#   'you',
#   'try',
#   'to',
#   'think',
#   'of',
#   'how',
#   'long',
#   'it',
#   'would',
#   'take',
#   'anyone',
#   'to',
#   'cover',
#   'the',
#   'same',
#   'distance',
#   'by',
#   'foot',
#   'or',
#   'the',
#   'amount',
#   'of',
#   'energy',
#   'spent',
#   'in',
#   'any',
#   'other',
#   'way',
#   'for',
#   'these',
#   'guys',
#   'to',
#   'go',
#   'miles',
#   'in',
#   'three',
#   'weeks',
#   'it',
#   'kind',
#   'of',
#   'unfathomable',
#   'without',
#   'the',
#   'machine',
#   'itself'],
#  ['that',
#   'true',
#   'it',
#   'interesting',
#   'too',
#   'these',
#   'guys',
#   'they',
#   'are',
#   'very',
#   'efficient',
#   'in',
#   'their',
#   'energy',
#   'use',
#   'but',
#   'the',
#   'amount',
#   'of',
#   'energy',
#   'that',
#   'they',
#   're',
#   'using',
#   'for',
#   'human',
#   'capacity',
#   'can',
#   'be',
#   'fairly',
#   'stunning',
#   'these',
#   'guys',
#   'are',
#   'burning',
#   'anywhere',
#   'between',
#   'six',
#   'and',
#   'calories',
#   'every',
#   'day',
#   'just',
#   'to',
#   'move',
#   'their',
#   'bicycles',
#   'over',
#   'the',
#   'terrain',
#   'nine',
#   'thousand',
#   'calories',
#   'is',
#   'the',
#   'upper',
#   'limits',
#   'on',
#   'some',
#   'of',
#   'those',
#   'more',
#   'difficult',
#   'mountain',
#   'stages',
#   'and',
#   'that',
#   'more',
#   'than',
#   'the',
#   'average',
#   'american',
#   'should',
#   'eat',
#   'in',
#   'four',
#   'plus',
#   'days',
#   'to',
#   'give',
#   'you',
#   'some',
#   'sense',
#   'of',
#   'scale',
#   'these',
#   'guys',
#   'turn',
#   'into',
#   'very',
#   'high',
#   'burning',
#   'engines',
#   'if',
#   'you',
#   'will'],
#  ['in', 'other', 'words', 'don', 'invite', 'them', 'out', 'to', 'dinner'],
#  ['yeah',
#   'you',
#   'be',
#   'if',
#   'you',
#   'have',
#   'to',
#   'pick',
#   'up',
#   'the',
#   'tab',
#   'you',
#   'be',
#   'in',
#   'some',
#   'trouble',
#   'for',
#   'sure'],
#  ['john', 'thanks', 'very', 'much', 'for', 'the', 'call'],
#  ['thank', 'you'],
#  ['bye',
#   'bye',
#   'there',
#   'is',
#   'also',
#   'as',
#   'we',
#   'mentioned',
#   'the',
#   'training',
#   'but',
#   'one',
#   'of',
#   'the',
#   'aspects',
#   'of',
#   'the',
#   'race',
#   'that',
#   'seems',
#   'to',
#   'startle',
#   'lot',
#   'of',
#   'people',
#   'is',
#   'they',
#   're',
#   'riding',
#   'through',
#   'these',
#   'little',
#   'towns',
#   'in',
#   'france',
#   'for',
#   'the',
#   'most',
#   'part',
#   'and',
#   'people',
#   'are',
#   'standing',
#   'right',
#   'by',
#   'the',
#   'roadsides',
#   'there',
#   'no',
#   'barriers',
#   'they',
#   'just',
#   'reach',
#   'out',
#   'and',
#   'touch',
#   'them',
#   'and',
#   'sometimes',
#   'they',
#   'do'],
#  ['that',
#   'right',
#   'one',
#   'of',
#   'the',
#   'very',
#   'cool',
#   'things',
#   'about',
#   'the',
#   'sport',
#   'is',
#   'it',
#   'does',
#   'give',
#   'the',
#   'public',
#   'chance',
#   'to',
#   'really',
#   'go',
#   'face',
#   'to',
#   'face',
#   'with',
#   'the',
#   'riders',
#   'on',
#   'the',
#   'roadway',
#   'sometimes',
#   'on',
#   'those',
#   'steep',
#   'climbs',
#   'you',
#   'll',
#   'see',
#   'just',
#   'walls',
#   'of',
#   'people',
#   'almost',
#   'blocking',
#   'the',
#   'road',
#   'and',
#   'then',
#   'moving',
#   'back',
#   'at',
#   'the',
#   'last',
#   'second',
#   'to',
#   'let',
#   'the',
#   'riders',
#   'slip',
#   'through',
#   'given',
#   'the',
#   'access',
#   'that',
#   'the',
#   'fans',
#   'have',
#   'and',
#   'there',
#   'can',
#   'be',
#   'you',
#   'know',
#   'hundreds',
#   'of',
#   'thousands',
#   'close',
#   'to',
#   'million',
#   'people',
#   'on',
#   'some',
#   'of',
#   'these',
#   'larger',
#   'mountainsides',
#   'it',
#   'is',
#   'remarkable',
#   'that',
#   'there',
#   'not',
#   'more',
#   'interference',
#   'from',
#   'fans'],
#  ['let',
#   'go',
#   'next',
#   'to',
#   'marshall',
#   'ph',
#   'marshall',
#   'with',
#   'us',
#   'from',
#   'holland',
#   'michigan'],
#  ['hello',
#   'the',
#   'reason',
#   'watch',
#   'the',
#   'tour',
#   'de',
#   'france',
#   'is',
#   'because',
#   'this',
#   'is',
#   'the',
#   'best',
#   'time',
#   'for',
#   'cyclist',
#   'like',
#   'myself',
#   'an',
#   'amateur',
#   'racer',
#   'to',
#   'enjoy',
#   'top',
#   'notch',
#   'live',
#   'coverage',
#   'otherwise',
#   'it',
#   'all',
#   'by',
#   'magazines',
#   'or',
#   'over',
#   'the',
#   'internet'],
#  ['the', 'magazines', 'are', 'of', 'course', 'brilliant'],
#  ['pardon'],
#  ['the', 'magazines', 'are', 'brilliant'],
#  ['magazines',
#   'are',
#   'brilliant',
#   'and',
#   'do',
#   'have',
#   'subscription',
#   'to',
#   'bicycling',
#   'magazine'],
#  ['oh', 'okay'],
#  ['but',
#   'it',
#   'the',
#   'best',
#   'because',
#   'you',
#   'have',
#   'every',
#   'type',
#   'of',
#   'racing',
#   'that',
#   'you',
#   'can',
#   'enjoy',
#   'you',
#   'have',
#   'the',
#   'mountains',
#   'you',
#   'have',
#   'sprinting',
#   'and',
#   'you',
#   'have',
#   'time',
#   'trials',
#   'so',
#   'no',
#   'matter',
#   'what',
#   'kind',
#   'of',
#   'cyclist',
#   'you',
#   'are',
#   'you',
#   'get',
#   'to',
#   'watch',
#   'all',
#   'the',
#   'world',
#   'greatest',
#   'cyclists',
#   'in',
#   'one',
#   'you',
#   'know',
#   'one',
#   'three',
#   'week',
#   'race',
#   'and',
#   'it',
#   'the',
#   'best',
#   'it',
#   'devour',
#   'it',
#   'every',
#   'night',
#   'and',
#   'find',
#   'excuses',
#   'to',
#   'be',
#   'at',
#   'home',
#   'during',
#   'the',
#   'day',
#   'to',
#   'watch',
#   'it',
#   'live'],
#  ['one',
#   'of',
#   'interesting',
#   'things',
#   'marshall',
#   'that',
#   'find',
#   'is',
#   'the',
#   'races',
#   'within',
#   'the',
#   'races',
#   'so',
#   'you',
#   'have',
#   'races',
#   'that',
#   'are',
#   'sprints',
#   'and',
#   'people',
#   'competing',
#   'for',
#   'the',
#   'sprint',
#   'championship',
#   'and',
#   'then',
#   'races',
#   'within',
#   'the',
#   'mountains',
#   'and',
#   'people',
#   'competing',
#   'to',
#   'be',
#   'the',
#   'king',
#   'of',
#   'the',
#   'mountains'],
#  ['those',
#   'are',
#   'great',
#   'because',
#   'it',
#   'actually',
#   'allows',
#   'you',
#   'to',
#   'pay',
#   'attention',
#   'on',
#   'individual',
#   'stages',
#   'more',
#   'so',
#   'than',
#   'the',
#   'overall',
#   'while',
#   'the',
#   'overall',
#   'is',
#   'the',
#   'top',
#   'prize',
#   'the',
#   'king',
#   'of',
#   'the',
#   'mountains',
#   'and',
#   'the',
#   'sprint',
#   'jersey',
#   'even',
#   'the',
#   'young',
#   'rider',
#   'jersey',
#   'which',
#   'is',
#   'the',
#   'white',
#   'jersey',
#   'are',
#   'prized',
#   'and',
#   'among',
#   'sprinters',
#   'which',
#   'is',
#   'my',
#   'favorite',
#   'competition',
#   'that',
#   'awesome',
#   'because',
#   'the',
#   'speed',
#   'that',
#   'they',
#   'hit',
#   'almost',
#   'kilometers',
#   'an',
#   'hour',
#   'for',
#   'huge',
#   'amount',
#   'of',
#   'wattage',
#   'it',
#   'just',
#   'amazing'],
#  ['hmm',
#   'marshall',
#   'thanks',
#   'very',
#   'much',
#   'for',
#   'the',
#   'phone',
#   'call',
#   'appreciate',
#   'it'],
#  ['you', 'bet'],
#  ['the',
#   'jerseys',
#   'he',
#   'mentioned',
#   'of',
#   'course',
#   'the',
#   'yellow',
#   'jersey',
#   'is',
#   'the',
#   'overall',
#   'leader',
#   'but',
#   'the',
#   'other',
#   'categories',
#   'have',
#   'all',
#   'jerseys',
#   'of',
#   'their',
#   'own',
#   'loren',
#   'mooney'],
#  ['yeah',
#   'that',
#   'right',
#   'the',
#   'yellow',
#   'jersey',
#   'the',
#   'overall',
#   'leader',
#   'and',
#   'that',
#   'is',
#   'the',
#   'rider',
#   'with',
#   'the',
#   'lowest',
#   'cumulative',
#   'time',
#   'at',
#   'the',
#   'end',
#   'of',
#   'the',
#   'three',
#   'weeks',
#   'the',
#   'green',
#   'sprinter',
#   'jersey',
#   'determined',
#   'by',
#   'points',
#   'often',
#   'who',
#   'has',
#   'the',
#   'best',
#   'sprint',
#   'at',
#   'the',
#   'end',
#   'but',
#   'there',
#   'are',
#   'also',
#   'some',
#   'intermediate',
#   'sprints',
#   'during',
#   'some',
#   'stages',
#   'the',
#   'polka',
#   'dot',
#   'jersey',
#   'is',
#   'for',
#   'the',
#   'best',
#   'mountain',
#   'climber',
#   'and',
#   'the',
#   'white',
#   'jersey',
#   'is',
#   'for',
#   'the',
#   'best',
#   'rider',
#   'years',
#   'of',
#   'age',
#   'or',
#   'under'],
#  ['let',
#   'go',
#   'next',
#   'to',
#   'rick',
#   'ph',
#   'rick',
#   'with',
#   'us',
#   'from',
#   'denver'],
#  ['hello', 'how', 'are', 'you', 'today'],
#  ['good', 'thanks'],
#  ['great',
#   'hey',
#   'just',
#   'love',
#   'hearing',
#   'show',
#   'about',
#   'the',
#   'tour',
#   'de',
#   'france',
#   'and',
#   'truly',
#   'love',
#   'watching',
#   'it',
#   'and',
#   'as',
#   'former',
#   'cyclist',
#   'spent',
#   'four',
#   'years',
#   'after',
#   'high',
#   'school',
#   'before',
#   'started',
#   'college',
#   'racing',
#   'bikes',
#   'but',
#   'would',
#   'propose',
#   'that',
#   'there',
#   'are',
#   'two',
#   'reasons',
#   'why',
#   'people',
#   'love',
#   'watching',
#   'the',
#   'tour',
#   'and',
#   'love',
#   'to',
#   'hear',
#   'your',
#   'guest',
#   'comments',
#   'on',
#   'these',
#   'number',
#   'one',
#   'is',
#   'the',
#   'cinematography',
#   'is',
#   'incredible',
#   'mean',
#   'you',
#   'really',
#   'you',
#   'don',
#   'just',
#   'watch',
#   'bike',
#   'race',
#   'when',
#   'you',
#   'watch',
#   'the',
#   'tour',
#   'each',
#   'morning',
#   'you',
#   'get',
#   'chance',
#   'to',
#   'see',
#   'some',
#   'of',
#   'the',
#   'most',
#   'beautiful',
#   'scenery',
#   'and',
#   'just',
#   'the',
#   'way',
#   'they',
#   'present',
#   'it',
#   'on',
#   'tv',
#   'it',
#   'much',
#   'more',
#   'than',
#   'just',
#   'sporting',
#   'event'],
#  ['and',
#   'the',
#   'second',
#   'reason',
#   'would',
#   'propose',
#   'people',
#   'love',
#   'watching',
#   'the',
#   'tour',
#   'de',
#   'france',
#   'is',
#   'mr',
#   'phil',
#   'liggett',
#   'it',
#   'the',
#   'british',
#   'gentleman',
#   'who',
#   'speaks',
#   'to',
#   'us',
#   'each',
#   'morning',
#   'not',
#   'just',
#   'about',
#   'the',
#   'race',
#   'and',
#   'the',
#   'current',
#   'riders',
#   'whom',
#   'he',
#   'seems',
#   'to',
#   'know',
#   'each',
#   'one',
#   'of',
#   'them',
#   'personally',
#   'but',
#   'about',
#   'the',
#   'history',
#   'of',
#   'the',
#   'race',
#   'the',
#   'history',
#   'of',
#   'france',
#   'the',
#   'history',
#   'of',
#   'cycling',
#   'the',
#   'history',
#   'of',
#   'whatever',
#   'you',
#   'like',
#   'phil',
#   'just',
#   'seems',
#   'to',
#   'have',
#   'so',
#   'many',
#   'stories',
#   'that',
#   'fill',
#   'what',
#   'is',
#   'very',
#   'long',
#   'day'],
#  ['mean',
#   'these',
#   'races',
#   'on',
#   'television',
#   'are',
#   'quite',
#   'long',
#   'and',
#   'yet',
#   'you',
#   'never',
#   'get',
#   'bored',
#   'because',
#   'each',
#   'time',
#   'he',
#   'starts',
#   'speaking',
#   'he',
#   'got',
#   'another',
#   'little',
#   'tidbit',
#   'to',
#   'share',
#   'with',
#   'you',
#   'so'],
#  ['well'],
#  ['find',
#   'that',
#   'the',
#   'cinematography',
#   'and',
#   'phil',
#   'just',
#   'leave',
#   'me',
#   'gripped',
#   'to',
#   'the',
#   'tv'],
#  ['thought',
#   'this',
#   'call',
#   'originally',
#   'from',
#   'the',
#   'french',
#   'ministry',
#   'of',
#   'tourism',
#   'but',
#   'it',
#   'turns',
#   'out',
#   'of',
#   'course',
#   'he',
#   'was',
#   'publicity',
#   'department',
#   'at',
#   'versus',
#   'so'],
#  ['well',
#   'would',
#   'love',
#   'to',
#   'know',
#   'what',
#   'your',
#   'guest',
#   'thinks',
#   'of',
#   'my',
#   'proposal',
#   'that',
#   'those',
#   'are',
#   'two',
#   'reasons',
#   'why',
#   'people',
#   'continue',
#   'to',
#   'watch',
#   'the',
#   'tour',
#   'despite',
#   'many',
#   'of',
#   'the',
#   'troubles',
#   'that',
#   'the',
#   'athletes',
#   'seem',
#   'to',
#   'create',
#   'for',
#   'themselves'],
#  ['loren'],
#  ['yeah',
#   'think',
#   'that',
#   'right',
#   'particularly',
#   'with',
#   'the',
#   'scenery',
#   'of',
#   'france',
#   'it',
#   'is',
#   'true',
#   'tour',
#   'of',
#   'the',
#   'country',
#   'the',
#   'route',
#   'changes',
#   'each',
#   'year',
#   'some',
#   'years',
#   'it',
#   'goes',
#   'in',
#   'circle',
#   'around',
#   'france',
#   'this',
#   'year',
#   'going',
#   'clockwise',
#   'where',
#   'it',
#   'hitting',
#   'the',
#   'alps',
#   'mountains',
#   'before',
#   'the',
#   'pyrenees',
#   'and',
#   'you',
#   're',
#   'seeing',
#   'tiny',
#   'villages',
#   'you',
#   're',
#   'seeing',
#   'just',
#   'breathtaking',
#   'mountainscapes',
#   'you',
#   'go',
#   'into',
#   'the',
#   'pyrenees',
#   'you',
#   'see',
#   'the',
#   'basque',
#   'flags',
#   'and',
#   'the',
#   'fans',
#   'wearing',
#   'orange',
#   'cheering'],
#  ['and',
#   'also',
#   'the',
#   'cinematography',
#   'that',
#   'they',
#   're',
#   'using',
#   'at',
#   'this',
#   'point',
#   'is',
#   'outstanding',
#   'you',
#   're',
#   'seeing',
#   'not',
#   'only',
#   'the',
#   'wide',
#   'shots',
#   'from',
#   'helicopters',
#   'but',
#   'these',
#   'cameramen',
#   'on',
#   'motorbikes',
#   'within',
#   'the',
#   'race',
#   'are',
#   'the',
#   'true',
#   'daredevils',
#   'of',
#   'the',
#   'race',
#   'they',
#   'get',
#   'some',
#   'amazing',
#   'footage'],
#  ['you',
#   're',
#   'also',
#   'seeing',
#   'in',
#   'some',
#   'of',
#   'the',
#   'sprint',
#   'stages',
#   'now',
#   'they',
#   'have',
#   'camera',
#   'that',
#   'goes',
#   'alongside',
#   'the',
#   'racers',
#   'at',
#   'upwards',
#   'of',
#   'miles',
#   'an',
#   'hour',
#   'sometimes',
#   'at',
#   'the',
#   'very',
#   'end',
#   'to',
#   'see',
#   'the',
#   'very',
#   'last',
#   'rocket',
#   'ship',
#   'efforts',
#   'of',
#   'the',
#   'sprinters',
#   'so',
#   'really',
#   'covering',
#   'it',
#   'from',
#   'all',
#   'angles',
#   'again',
#   'getting',
#   'up',
#   'close',
#   'getting',
#   'into',
#   'the',
#   'riders',
#   'faces',
#   'at',
#   'the',
#   'moment',
#   'of',
#   'the',
#   'action',
#   'is',
#   'pretty',
#   'remarkable',
#   'stuff'],
#  ['rick', 'thanks', 'very', 'much', 'for', 'the', 'call'],
#  ['thank', 'you'],
#  ['the',
#   'current',
#   'issue',
#   'of',
#   'bicycling',
#   'magazine',
#   'offers',
#   'tour',
#   'de',
#   'france',
#   'fans',
#   'guide',
#   'its',
#   'editor',
#   'in',
#   'chief',
#   'loren',
#   'mooney',
#   'is',
#   'with',
#   'us',
#   'you',
#   're',
#   'listening',
#   'to',
#   'talk',
#   'of',
#   'the',
#   'nation',
#   'from',
#   'npr',
#   'news'],
#  ['and',
#   'here',
#   'some',
#   'emails',
#   'that',
#   'we',
#   'have',
#   'this',
#   'from',
#   'matt',
#   'ph',
#   'in',
#   'liverpool',
#   'new',
#   'york',
#   'personally',
#   'couldn',
#   'name',
#   'five',
#   'riders',
#   'but',
#   'love',
#   'to',
#   'see',
#   'the',
#   'french',
#   'countryside',
#   'and',
#   'this',
#   'is',
#   'from',
#   'amon',
#   'ph',
#   'in',
#   'sunnyvale',
#   'california',
#   'as',
#   'an',
#   'irishman',
#   'was',
#   'inspired',
#   'by',
#   'the',
#   'great',
#   'sean',
#   'kelly',
#   'and',
#   'stephen',
#   'roche',
#   'in',
#   'the',
#   'roche',
#   'began',
#   'as',
#   'paperboy',
#   'racing',
#   'his',
#   'friends',
#   'delivering',
#   'newspapers',
#   'in',
#   'dublin',
#   'when',
#   'he',
#   'was',
#   'kid',
#   'he',
#   'went',
#   'on',
#   'to',
#   'win',
#   'the',
#   'tour',
#   'de',
#   'france',
#   'in',
#   'dramatic',
#   'finish',
#   'against',
#   'spaniard',
#   'pedro',
#   'delgado',
#   'in',
#   'the',
#   'first',
#   'and',
#   'only',
#   'irishman',
#   'ever',
#   'to',
#   'do',
#   'so'],
#  ['years',
#   'old',
#   'and',
#   'still',
#   'racing',
#   'for',
#   'the',
#   'los',
#   'gatos',
#   'club',
#   'here',
#   'in',
#   'california',
#   'greg',
#   'lemond',
#   'old',
#   'club',
#   'so',
#   'that',
#   'of',
#   'course',
#   'the',
#   'other',
#   'great',
#   'american',
#   'rider',
#   'before',
#   'lance',
#   'armstrong'],
#  ['and',
#   'this',
#   'is',
#   'from',
#   'greg',
#   'ph',
#   'in',
#   'oklahoma',
#   'city',
#   'it',
#   'sporting',
#   'event',
#   'like',
#   'no',
#   'other',
#   'unlike',
#   'any',
#   'other',
#   'sport',
#   'it',
#   'involves',
#   'individual',
#   'team',
#   'individual',
#   'and',
#   'team',
#   'goals',
#   'none',
#   'of',
#   'which',
#   'can',
#   'be',
#   'realized',
#   'without',
#   'the',
#   'other',
#   'it',
#   'has',
#   'history',
#   'courage',
#   'teamwork',
#   'and',
#   'host',
#   'of',
#   'unpredictable',
#   'variables',
#   'watch',
#   'every',
#   'day',
#   'on',
#   'the',
#   'edge',
#   'of',
#   'my',
#   'couch',
#   'let',
#   'see',
#   'if',
#   'can',
#   'go',
#   'next',
#   'to',
#   'this',
#   'is',
#   'sterling',
#   'ph',
#   'sterling',
#   'with',
#   'us',
#   'from',
#   'st',
#   'helena',
#   'in',
#   'california'],
#  ['how', 'are', 'you', 'all', 'today'],
#  ['very', 'well', 'thanks'],
#  ['fantastic',
#   'loren',
#   'love',
#   'your',
#   'magazine',
#   'you',
#   'know',
#   'think',
#   'one',
#   'of',
#   'the',
#   'things',
#   'that',
#   'that',
#   'one',
#   'of',
#   'your',
#   'callers',
#   'mentioned',
#   'you',
#   'know',
#   'in',
#   'the',
#   'dual',
#   'proposal',
#   'you',
#   'do',
#   'get',
#   'to',
#   'see',
#   'such',
#   'an',
#   'amazing',
#   'part',
#   'of',
#   'the',
#   'world',
#   'and',
#   'you',
#   'could',
#   'see',
#   'it',
#   'in',
#   'great',
#   'detail',
#   'but',
#   'think',
#   'the',
#   'thing',
#   'that',
#   'really',
#   'draws',
#   'me',
#   'is',
#   'the',
#   'community',
#   'that',
#   'gets',
#   'created',
#   'every',
#   'year',
#   'when',
#   'the',
#   'tour',
#   'is',
#   'broadcast',
#   'the',
#   'communities',
#   'of',
#   'cyclists',
#   'and',
#   'triathletes',
#   'out',
#   'you',
#   'know',
#   'all',
#   'throughout',
#   'the',
#   'united',
#   'states',
#   'all',
#   'gather',
#   'together',
#   'and',
#   'you',
#   'know',
#   'discuss',
#   'this',
#   'talk',
#   'about',
#   'this'],
#  ['was',
#   'in',
#   'bike',
#   'shop',
#   'yesterday',
#   'in',
#   'napa',
#   'valley',
#   'and',
#   'getting',
#   'my',
#   'bike',
#   'work',
#   'done',
#   'and',
#   'year',
#   'old',
#   'woman',
#   'walked',
#   'in',
#   'and',
#   'said',
#   'you',
#   'know',
#   'want',
#   'to',
#   'buy',
#   'bike',
#   'you',
#   'know',
#   'was',
#   'watching',
#   'the',
#   'tour',
#   'and',
#   'want',
#   'to',
#   'get',
#   'out',
#   'on',
#   'my',
#   'bike',
#   'and',
#   'you',
#   'know',
#   'happen',
#   'to',
#   'have',
#   'year',
#   'old',
#   'mother',
#   'who',
#   'got',
#   'trek',
#   'carbon',
#   'bike',
#   'and',
#   'you',
#   'know',
#   'she',
#   'all',
#   'inspired',
#   'and',
#   'think',
#   'that',
#   'the',
#   'thing',
#   'that',
#   'so',
#   'compelling',
#   'is',
#   'the',
#   'sense',
#   'of',
#   'community',
#   'you',
#   'know',
#   'these',
#   'something',
#   'days',
#   'create',
#   'you',
#   'know',
#   'in',
#   'the'],
#  ['and',
#   'it',
#   'not',
#   'you',
#   'don',
#   'see',
#   'that',
#   'mean',
#   'think',
#   'you',
#   'see',
#   'that',
#   'in',
#   'the',
#   'world',
#   'cup',
#   'with',
#   'football',
#   'but',
#   'soccer',
#   'but',
#   'you',
#   'don',
#   'see',
#   'that',
#   'in',
#   'any',
#   'other',
#   'sports',
#   'where',
#   'people',
#   'get',
#   'together',
#   'and',
#   'they',
#   're',
#   'really',
#   'it',
#   'participatory',
#   'as',
#   'well'],
#  ['well',
#   'the',
#   'sport',
#   'loren',
#   'mooney',
#   'has',
#   'natural',
#   'clubhouse',
#   'the',
#   'bike',
#   'shop'],
#  ['that',
#   'true',
#   'the',
#   'bike',
#   'shop',
#   'is',
#   'our',
#   'clubhouse',
#   'sports',
#   'bar',
#   'church',
#   'all',
#   'in',
#   'one',
#   'for',
#   'the',
#   'cyclists',
#   'and',
#   'think',
#   'you',
#   're',
#   'absolutely',
#   'right',
#   'you',
#   'drew',
#   'the',
#   'world',
#   'cup',
#   'analogy',
#   'there',
#   'and',
#   'think',
#   'that',
#   'good',
#   'one',
#   'because',
#   'cycling',
#   'much',
#   'like',
#   'soccer',
#   'in',
#   'the',
#   'is',
#   'rarely',
#   'shown',
#   'on',
#   'television',
#   'with',
#   'you',
#   'know',
#   'with',
#   'any',
#   'in',
#   'any',
#   'depth',
#   'and',
#   'so',
#   'this',
#   'is',
#   'our',
#   'time',
#   'to',
#   'celebrate',
#   'much',
#   'like',
#   'you',
#   'saw',
#   'the',
#   'rather',
#   'large',
#   'soccer',
#   'community',
#   'in',
#   'the',
#   'gathering',
#   'in',
#   'sports',
#   'bars',
#   'watching',
#   'the',
#   'world',
#   'cup'],
#  ['this',
#   'is',
#   'the',
#   'time',
#   'when',
#   'the',
#   'cyclists',
#   'gather',
#   'together',
#   'watch',
#   'stop',
#   'by',
#   'the',
#   'bike',
#   'shop',
#   'afterward',
#   'get',
#   'into',
#   'friendly',
#   'arguments',
#   'it',
#   'funny',
#   'how',
#   'many',
#   'times',
#   'just',
#   'this',
#   'year',
#   'have',
#   'watched',
#   'the',
#   'tour',
#   'de',
#   'france',
#   'live',
#   'on',
#   'tv',
#   'then',
#   'gone',
#   'out',
#   'for',
#   'bike',
#   'ride',
#   'and',
#   'see',
#   'lot',
#   'of',
#   'other',
#   'cyclists',
#   'leaving',
#   'at',
#   'the',
#   'same',
#   'time',
#   'knowing',
#   'that',
#   'they',
#   'had',
#   'just',
#   'watched',
#   'the',
#   'stage',
#   'as',
#   'well',
#   'and',
#   'now',
#   'are',
#   'free',
#   'for',
#   'the',
#   'rest',
#   'of',
#   'their',
#   'day',
#   'to',
#   'go',
#   'out',
#   'and',
#   'do',
#   'their',
#   'own',
#   'bike',
#   'ride'],
#  ['sterling',
#   'thanks',
#   'very',
#   'much',
#   'for',
#   'the',
#   'call',
#   'appreciate',
#   'it'],
#  ['yeah'],
#  ['email',
#   'from',
#   'sean',
#   'ph',
#   'in',
#   'cleveland',
#   'the',
#   'tour',
#   'de',
#   'france',
#   'reminds',
#   'me',
#   'of',
#   'what',
#   'the',
#   'human',
#   'body',
#   'can',
#   'achieve',
#   'with',
#   'massive',
#   'amounts',
#   'of',
#   'dedication',
#   'lance',
#   'is',
#   'my',
#   'hero',
#   'all',
#   'of',
#   'these',
#   'riders',
#   'are',
#   'my',
#   'hero',
#   'and',
#   'this',
#   'is',
#   'from',
#   'robert',
#   'ph',
#   'in',
#   'columbus',
#   'ohio',
#   'because',
#   'it',
#   'inspires',
#   'me',
#   'to',
#   'write',
#   'and',
#   'because',
#   'quote',
#   'you',
#   're',
#   'not',
#   'having',
#   'fun',
#   'until',
#   'you',
#   're',
#   'not',
#   'having',
#   'fun',
#   'and',
#   'suppose',
#   'that',
#   'last',
#   'part',
#   'is',
#   'because',
#   'it',
#   'drives',
#   'you',
#   'to',
#   'do',
#   'things',
#   'you',
#   'didn',
#   'think',
#   'you',
#   'could',
#   'do'],
#  ['yeah',
#   'absolutely',
#   'think',
#   'the',
#   'tour',
#   'is',
#   'widely',
#   'called',
#   'the',
#   'most',
#   'difficult',
#   'endurance',
#   'event',
#   'in',
#   'the',
#   'world',
#   'it',
#   'funny',
#   'when',
#   'you',
#   'look',
#   'at',
#   'some',
#   'of',
#   'these',
#   'racers',
#   'you',
#   'look',
#   'at',
#   'them',
#   'at',
#   'the',
#   'beginning',
#   'of',
#   'the',
#   'tour',
#   'de',
#   'france',
#   'and',
#   'at',
#   'the',
#   'end',
#   'of',
#   'the',
#   'tour',
#   'de',
#   'france',
#   'it',
#   'to',
#   'me',
#   'not',
#   'unlike',
#   'when',
#   'you',
#   'see',
#   'president',
#   'about',
#   'to',
#   'finish',
#   'his',
#   'eighth',
#   'year',
#   'end',
#   'of',
#   'the',
#   'second',
#   'term',
#   'of',
#   'office',
#   'and',
#   'you',
#   'look',
#   'back',
#   'at',
#   'photograph',
#   'of',
#   'the',
#   'first',
#   'inauguration',
#   'and',
#   'you',
#   'realize',
#   'just',
#   'how',
#   'much',
#   'the',
#   'president',
#   'has',
#   'aged',
#   'in',
#   'those',
#   'eight',
#   'years'],
#  ['you',
#   'look',
#   'at',
#   'tour',
#   'de',
#   'france',
#   'rider',
#   'first',
#   'day',
#   'and',
#   'then',
#   'on',
#   'the',
#   'podium',
#   'in',
#   'paris',
#   'and',
#   'they',
#   'almost',
#   'look',
#   'like',
#   'different',
#   'person',
#   'they',
#   're',
#   'very',
#   'gaunt',
#   'their',
#   'whole',
#   'body',
#   'composition',
#   'has',
#   'changed',
#   'just',
#   'from',
#   'having',
#   'been',
#   'through',
#   'the',
#   'rigors',
#   'of',
#   'the',
#   'event'],
#  ['loren',
#   'mooney',
#   'thanks',
#   'very',
#   'much',
#   'for',
#   'your',
#   'time',
#   'today',
#   'we',
#   'appreciate',
#   'it'],
#  ['thank', 'you'],
#  ['and',
#   'good',
#   'watching',
#   'loren',
#   'mooney',
#   'is',
#   'editor',
#   'in',
#   'chief',
#   'of',
#   'bicycling',
#   'magazine',
#   'and',
#   'joined',
#   'us',
#   'from',
#   'our',
#   'bureau',
#   'in',
#   'new',
#   'york'],
#  ['neal',
#   'conan',
#   'this',
#   'is',
#   'talk',
#   'of',
#   'the',
#   'nation',
#   'from',
#   'npr',
#   'news',
#   'join',
#   'us',
#   'tomorrow'],
#  ['this',
#   'is',
#   'talk',
#   'of',
#   'the',
#   'nation',
#   'im',
#   'neal',
#   'conan',
#   'in',
#   'washington'],
#  ['the',
#   'supreme',
#   'court',
#   'handed',
#   'down',
#   'rulings',
#   'in',
#   'two',
#   'important',
#   'cases',
#   'earlier',
#   'today',
#   'first',
#   'in',
#   'seven',
#   'to',
#   'two',
#   'decision',
#   'the',
#   'high',
#   'court',
#   'agreed',
#   'that',
#   'the',
#   'government',
#   'can',
#   'indefinitely',
#   'hold',
#   'convicts',
#   'considered',
#   'sexually',
#   'dangerous',
#   'even',
#   'after',
#   'their',
#   'prison',
#   'terms',
#   'are',
#   'complete'],
#  ['in',
#   'the',
#   'second',
#   'case',
#   'decided',
#   'five',
#   'to',
#   'four',
#   'the',
#   'court',
#   'said',
#   'it',
#   'is',
#   'cruel',
#   'and',
#   'unusual',
#   'punishment',
#   'to',
#   'sentence',
#   'minors',
#   'to',
#   'life',
#   'without',
#   'the',
#   'possibility',
#   'of',
#   'parole',
#   'if',
#   'murder',
#   'is',
#   'not',
#   'involved'],
#  ['later',
#   'in',
#   'the',
#   'program',
#   'comic',
#   'book',
#   'also',
#   'ran',
#   'sprints',
#   'to',
#   'the',
#   'top',
#   'of',
#   'the',
#   'movie',
#   'box',
#   'office',
#   'charts',
#   'glen',
#   'weldon',
#   'joins',
#   'us',
#   'on',
#   'iron',
#   'man',
#   'but',
#   'first',
#   'the',
#   'supreme',
#   'court',
#   'rulings'],
#  ['if',
#   'either',
#   'of',
#   'these',
#   'cases',
#   'affects',
#   'you',
#   'give',
#   'us',
#   'call',
#   'tell',
#   'us',
#   'how',
#   'email',
#   'us',
#   'talk',
#   'npr',
#   'org',
#   'you',
#   'can',
#   'also',
#   'join',
#   'the',
#   'conversation',
#   'via',
#   'our',
#   'website',
#   'thats',
#   'at',
#   'npr',
#   'org',
#   'click',
#   'on',
#   'talk',
#   'of',
#   'the',
#   'nation'],
#  ['we',
#   'begin',
#   'with',
#   'david',
#   'savage',
#   'who',
#   'covers',
#   'the',
#   'court',
#   'for',
#   'the',
#   'los',
#   'angeles',
#   'times',
#   'and',
#   'the',
#   'chicago',
#   'tribune',
#   'he',
#   'joins',
#   'us',
#   'today',
#   'by',
#   'phone',
#   'from',
#   'his',
#   'office',
#   'david',
#   'always',
#   'good',
#   'to',
#   'have',
#   'you',
#   'with',
#   'us',
#   'thanks',
#   'for',
#   'your',
#   'time'],
#  ['hi', 'neal'],
#  ['and',
#   'let',
#   'take',
#   'these',
#   'one',
#   'at',
#   'time',
#   'solid',
#   'majority',
#   'ruled',
#   'it',
#   'constitutional',
#   'to',
#   'hold',
#   'convict',
#   'even',
#   'after',
#   'he',
#   'completes',
#   'his',
#   'sentence'],
#  ['yes',
#   'and',
#   'neal',
#   'this',
#   'case',
#   'actually',
#   'was',
#   'not',
#   'dispute',
#   'about',
#   'what',
#   'you',
#   'might',
#   'think',
#   'it',
#   'was',
#   'about',
#   'which',
#   'is',
#   'is',
#   'that',
#   'fair'],
#  ['yeah'],
#  ['about',
#   'years',
#   'ago',
#   'in',
#   'case',
#   'from',
#   'kansas',
#   'the',
#   'court',
#   'upheld',
#   'these',
#   'after',
#   'the',
#   'fact',
#   'punishments',
#   'involving',
#   'sexual',
#   'criminals',
#   'they',
#   'said',
#   'that',
#   'they',
#   'were',
#   'not',
#   'retroactive',
#   'and',
#   'it',
#   'was',
#   'not',
#   'violation',
#   'of',
#   'due',
#   'process',
#   'of',
#   'law'],
#  ['so',
#   'it',
#   'actually',
#   'been',
#   'clear',
#   'for',
#   'while',
#   'as',
#   'constitutional',
#   'matter',
#   'as',
#   'matter',
#   'of',
#   'individual',
#   'rights',
#   'the',
#   'government',
#   'could',
#   'hold',
#   'somebody',
#   'after',
#   'they',
#   'served',
#   'their',
#   'term'],
#  ['because', 'of', 'what', 'they', 'might', 'do'],
#  ['correct',
#   'last',
#   'year',
#   'however',
#   'federal',
#   'appeals',
#   'court',
#   'struck',
#   'down',
#   'the',
#   'federal',
#   'law',
#   'on',
#   'the',
#   'grounds',
#   'that',
#   'congress',
#   'didn',
#   'have',
#   'the',
#   'authority',
#   'to',
#   'pass',
#   'such',
#   'law',
#   'there',
#   'is',
#   'no',
#   'federal',
#   'police',
#   'power',
#   'they',
#   'say',
#   'and',
#   'that',
#   'congress',
#   'only',
#   'has',
#   'the',
#   'powers',
#   'that',
#   'are',
#   'in',
#   'the',
#   'constitution',
#   'the',
#   'power',
#   'to',
#   'regulate',
#   'interstate',
#   'commerce'],
#  ['what',
#   'the',
#   'court',
#   'said',
#   'today',
#   'with',
#   'stephen',
#   'breyer',
#   'writing',
#   'very',
#   'broad',
#   'opinion',
#   'was',
#   'that',
#   'congress',
#   'can',
#   'pass',
#   'laws',
#   'that',
#   'are',
#   'necessary',
#   'and',
#   'proper',
#   'to',
#   'carry',
#   'out',
#   'its',
#   'aims',
#   'and',
#   'he',
#   'wrote',
#   'an',
#   'opinion',
#   'that',
#   'said',
#   'any',
#   'law',
#   'that',
#   'sort',
#   'of',
#   'rationally',
#   'related',
#   'to',
#   'some',
#   'aim',
#   'that',
#   'congress',
#   'has',
#   'it',
#   'is',
#   'constitutional'],
#  ['you', 'said', 'it', 'better', 'neal'],
#  ['the',
#   'atlantic',
#   'hurricane',
#   'season',
#   'officially',
#   'ends',
#   'today',
#   'in',
#   'the',
#   'united',
#   'states',
#   'likely',
#   'will',
#   'be',
#   'remembered',
#   'as',
#   'moderately',
#   'bad',
#   'year',
#   'for',
#   'storms',
#   'but',
#   'in',
#   'cuba',
#   'this',
#   'season',
#   'will',
#   'go',
#   'down',
#   'as',
#   'perhaps',
#   'the',
#   'worst',
#   'season',
#   'ever',
#   'npr',
#   'jon',
#   'hamilton',
#   'has',
#   'the',
#   'story'],
#  ['eight',
#   'hurricanes',
#   'formed',
#   'in',
#   'the',
#   'north',
#   'atlantic',
#   'and',
#   'caribbean',
#   'this',
#   'year',
#   'three',
#   'of',
#   'them',
#   'all',
#   'major',
#   'storms',
#   'hit',
#   'cuba',
#   'alexis',
#   'fernandez',
#   'ph',
#   'was',
#   'in',
#   'baracoa',
#   'city',
#   'on',
#   'the',
#   'eastern',
#   'tip',
#   'of',
#   'cuba',
#   'when',
#   'hurricane',
#   'ike',
#   'made',
#   'landfall',
#   'on',
#   'september'],
#  ['through',
#   'translator',
#   'the',
#   'waves',
#   'were',
#   'as',
#   'high',
#   'as',
#   'top',
#   'of',
#   'the',
#   'buildings',
#   'and',
#   'some',
#   'of',
#   'those',
#   'buildings',
#   'were',
#   'five',
#   'stories',
#   'high',
#   'this',
#   'in',
#   'turn',
#   'started',
#   'the',
#   'destruction',
#   'of',
#   'homes',
#   'people',
#   'homes',
#   'that',
#   'were',
#   'along',
#   'the',
#   'beach',
#   'area',
#   'homes',
#   'that',
#   'people',
#   'had',
#   'worked',
#   'all',
#   'their',
#   'lives',
#   'for',
#   'were',
#   'lost',
#   'in',
#   'matter',
#   'of',
#   'minutes'],
#  ['fernandez',
#   'teaches',
#   'history',
#   'at',
#   'the',
#   'university',
#   'in',
#   'baracoa',
#   'he',
#   'says',
#   'more',
#   'than',
#   'homes',
#   'were',
#   'damaged',
#   'and',
#   'hundreds',
#   'destroyed',
#   'ike',
#   'would',
#   'go',
#   'on',
#   'to',
#   'scour',
#   'the',
#   'entire',
#   'length',
#   'of',
#   'cuba',
#   'before',
#   'moving',
#   'into',
#   'the',
#   'gulf',
#   'of',
#   'mexico',
#   'couple',
#   'of',
#   'weeks',
#   'earlier',
#   'hurricane',
#   'gustav',
#   'had',
#   'plowed',
#   'across',
#   'the',
#   'western',
#   'part',
#   'of',
#   'the',
#   'country',
#   'and',
#   'in',
#   'early',
#   'november',
#   'hurricane',
#   'paloma',
#   'struck',
#   'the',
#   'central',
#   'coast',
#   'near',
#   'santa',
#   'cruz',
#   'del',
#   'sur',
#   'fernandez',
#   'says',
#   'it',
#   'been',
#   'the',
#   'worst',
#   'year',
#   'for',
#   'hurricanes',
#   'in',
#   'his',
#   'lifetime'],
#  ['through',
#   'translator',
#   'in',
#   'the',
#   'we',
#   'suffered',
#   'lot',
#   'from',
#   'hurricane',
#   'flora',
#   'there',
#   'were',
#   'great',
#   'floods',
#   'there',
#   'were',
#   'hundreds',
#   'of',
#   'deaths',
#   'in',
#   'this',
#   'series',
#   'of',
#   'hurricanes',
#   'there',
#   'been',
#   'lot',
#   'of',
#   'economic',
#   'damage',
#   'but',
#   'in',
#   'human',
#   'life',
#   'it',
#   'hasn',
#   'been',
#   'as',
#   'bad',
#   'because',
#   'the',
#   'state',
#   'has',
#   'been',
#   'able',
#   'to',
#   'control',
#   'and',
#   'help',
#   'us',
#   'evacuate',
#   'so',
#   'that',
#   'the',
#   'damage',
#   'in',
#   'human',
#   'lives',
#   'is',
#   'minimal'],
#  ['the',
#   'storms',
#   'did',
#   'more',
#   'than',
#   'billion',
#   'of',
#   'damage',
#   'in',
#   'cuba',
#   'and',
#   'left',
#   'tens',
#   'of',
#   'thousands',
#   'homeless',
#   'but',
#   'only',
#   'handful',
#   'of',
#   'people',
#   'died',
#   'one',
#   'reason',
#   'is',
#   'cuba',
#   'highly',
#   'organized',
#   'evacuation',
#   'system',
#   'another',
#   'reason',
#   'is',
#   'that',
#   'cuban',
#   'meteorologists',
#   'work',
#   'closely',
#   'with',
#   'their',
#   'counterparts',
#   'to',
#   'forecast',
#   'and',
#   'track',
#   'storms',
#   'cuba',
#   'even',
#   'allows',
#   'hurricane',
#   'hunter',
#   'aircraft',
#   'to',
#   'fly',
#   'into',
#   'cuban',
#   'airspace',
#   'and',
#   'then',
#   'there',
#   'cuba',
#   'chief',
#   'hurricane',
#   'forecaster',
#   'jose',
#   'rubiera'],
#  ['soundbite',
#   'of',
#   'hurricane',
#   'forecaster',
#   'jose',
#   'rubiera',
#   'on',
#   'cuban',
#   'tv'],
#  ['that',
#   'rubiera',
#   'on',
#   'cuban',
#   'television',
#   'describing',
#   'ike',
#   'he',
#   'fixture',
#   'on',
#   'cuban',
#   'tv',
#   'anytime',
#   'storm',
#   'is',
#   'on',
#   'the',
#   'way',
#   'and',
#   'viewers',
#   'pay',
#   'attention',
#   'to',
#   'his',
#   'warnings',
#   'caribbean',
#   'nations',
#   'with',
#   'less',
#   'expertise',
#   'and',
#   'infrastructure',
#   'were',
#   'badly',
#   'hurt',
#   'by',
#   'hurricanes',
#   'this',
#   'season',
#   'in',
#   'haiti',
#   'hundreds',
#   'of',
#   'people',
#   'died',
#   'in',
#   'the',
#   'this',
#   'year',
#   'hurricanes',
#   'struck',
#   'texas',
#   'and',
#   'louisiana',
#   'hurricane',
#   'ike',
#   'regained',
#   'much',
#   'of',
#   'its',
#   'strength',
#   'after',
#   'passing',
#   'over',
#   'cuba',
#   'then',
#   'it',
#   'weakened',
#   'to',
#   'category',
#   'two',
#   'storm',
#   'before',
#   'making',
#   'landfall',
#   'near',
#   'galveston',
#   'texas',
#   'even',
#   'so',
#   'ike',
#   'killed',
#   'more',
#   'than',
#   'people',
#   'in',
#   'the',
#   'and',
#   'caused',
#   'damage',
#   'of',
#   'more',
#   'than',
#   'billion',
#   'gerry',
#   'bell',
#   'is',
#   'the',
#   'lead',
#   'seasonal',
#   'forecaster',
#   'at',
#   'the',
#   'national',
#   'oceanic',
#   'and',
#   'atmospheric',
#   'administration',
#   'he',
#   'says',
#   'there',
#   'are',
#   'several',
#   'reasons',
#   'ike',
#   'was',
#   'so',
#   'dangerous',
#   'even',
#   'though',
#   'its',
#   'wind',
#   'speeds',
#   'weren',
#   'that',
#   'high'],
#  ['the',
#   'tremendous',
#   'storm',
#   'surge',
#   'the',
#   'very',
#   'long',
#   'track',
#   'over',
#   'water',
#   'where',
#   'the',
#   'hurricane',
#   'could',
#   'really',
#   'really',
#   'pile',
#   'up',
#   'the',
#   'water',
#   'also',
#   'the',
#   'speed',
#   'of',
#   'movement',
#   'of',
#   'the',
#   'storm',
#   'if',
#   'it',
#   'slow',
#   'moving',
#   'hurricane',
#   'it',
#   'going',
#   'to',
#   'stay',
#   'over',
#   'any',
#   'given',
#   'area',
#   'longer',
#   'and',
#   'obviously',
#   'increase',
#   'the',
#   'potential',
#   'for',
#   'more',
#   'damage'],
#  ['hurricane',
#   'gustav',
#   'strengthened',
#   'to',
#   'category',
#   'three',
#   'storm',
#   'in',
#   'the',
#   'gulf',
#   'of',
#   'mexico',
#   'officials',
#   'evacuated',
#   'new',
#   'orleans',
#   'and',
#   'residents',
#   'feared',
#   'another',
#   'katrina',
#   'but',
#   'gustav',
#   'ultimately',
#   'weakened',
#   'to',
#   'category',
#   'two',
#   'storm',
#   'and',
#   'veered',
#   'west',
#   'of',
#   'new',
#   'orleans',
#   'at',
#   'the',
#   'start',
#   'of',
#   'the',
#   'hurricane',
#   'season',
#   'gerry',
#   'bell',
#   'had',
#   'predicted',
#   'busy',
#   'year',
#   'and',
#   'he',
#   'was',
#   'right'],
#  ['we',
#   'had',
#   'named',
#   'storms',
#   'eight',
#   'hurricanes',
#   'and',
#   'five',
#   'major',
#   'hurricanes',
#   'and',
#   'that',
#   'certainly',
#   'consistent',
#   'with',
#   'what',
#   'the',
#   'forecasts',
#   'were',
#   'for',
#   'lot',
#   'of',
#   'activity',
#   'this',
#   'season'],
#  ['bell',
#   'says',
#   'it',
#   'too',
#   'soon',
#   'to',
#   'say',
#   'much',
#   'about',
#   'next',
#   'year',
#   'but',
#   'he',
#   'adds',
#   'that',
#   'the',
#   'atlantic',
#   'is',
#   'in',
#   'period',
#   'of',
#   'high',
#   'hurricane',
#   'activity',
#   'that',
#   'likely',
#   'to',
#   'continue',
#   'for',
#   'another',
#   'decade',
#   'or',
#   'more',
#   'jon',
#   'hamilton',
#   'npr',
#   'news'],
#  ['not',
#   'week',
#   'goes',
#   'by',
#   'there',
#   'isn',
#   'some',
#   'story',
#   'about',
#   'endangered',
#   'newspapers',
#   'or',
#   'layoffs',
#   'in',
#   'the',
#   'broadcasting',
#   'and',
#   'entertainment',
#   'industry',
#   'now',
#   'there',
#   'bad',
#   'news',
#   'from',
#   'the',
#   'world',
#   'of',
#   'publishing',
#   'where',
#   'major',
#   'houses',
#   'have',
#   'laid',
#   'off',
#   'staff',
#   'restructured',
#   'management',
#   'limited',
#   'the',
#   'number',
#   'of',
#   'manuscripts',
#   'they',
#   'buy',
#   'charlotte',
#   'abbott',
#   'is',
#   'contributing',
#   'editor',
#   'for',
#   'publishers',
#   'weekly',
#   'and',
#   'joins',
#   'us',
#   'from',
#   'new',
#   'york',
#   'thanks',
#   'so',
#   'much',
#   'for',
#   'being',
#   'with',
#   'us'],
#  ['thanks', 'for', 'having', 'me', 'scott'],
#  ['so', 'what', 'business', 'like', 'this', 'year'],
#  ['book', 'sales', 'have', 'definitely', 'slipped'],
#  ['what', 'your', 'analysis', 'of', 'what', 'driven', 'sales', 'down', 'then'],
#  ['well',
#   'the',
#   'general',
#   'retail',
#   'falloff',
#   'think',
#   'has',
#   'had',
#   'big',
#   'big',
#   'effect',
#   'interestingly',
#   'children',
#   'fiction',
#   'is',
#   'stronger',
#   'than',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'book',
#   'publishing',
#   'categories',
#   'think',
#   'people',
#   'do',
#   'not',
#   'feel',
#   'that',
#   'books',
#   'are',
#   'luxury',
#   'for',
#   'children',
#   'perhaps',
#   'the',
#   'way',
#   'they',
#   'might',
#   'for',
#   'adults',
#   'and',
#   'also',
#   'hear',
#   'that',
#   'libraries',
#   'are',
#   'seeing',
#   'lot',
#   'of',
#   'activities',
#   'so',
#   'think',
#   'it',
#   'not',
#   'that',
#   'people',
#   'are',
#   'not',
#   'reading',
#   'it',
#   'that',
#   'they',
#   're',
#   'not',
#   'buying',
#   'books',
#   'and',
#   'are',
#   'finding',
#   'other',
#   'ways',
#   'to',
#   'get',
#   'their',
#   'reading',
#   'fix',
#   'satisfied',
#   'except',
#   'in',
#   'the',
#   'case',
#   'of',
#   'children',
#   'where',
#   'they',
#   'are',
#   'buying',
#   'books'],
#  ['well',
#   'that',
#   'raises',
#   'this',
#   'question',
#   'we',
#   've',
#   'seen',
#   'the',
#   'introduction',
#   'of',
#   'electronic',
#   'readers',
#   'ebooks',
#   'the',
#   'kindle',
#   'from',
#   'amazon',
#   'and',
#   'the',
#   'sony',
#   'reader',
#   'how',
#   'are',
#   'they',
#   'selling',
#   'does',
#   'this',
#   'represent',
#   'whole',
#   'new',
#   'movement',
#   'in',
#   'the',
#   'book',
#   'industry'],
#  ['it',
#   'does',
#   'in',
#   'some',
#   'ways',
#   'think',
#   'it',
#   'very',
#   'notable',
#   'certainly',
#   'and',
#   'as',
#   'far',
#   'as',
#   'price',
#   'point',
#   'goes',
#   'ebooks',
#   'are',
#   'certainly',
#   'the',
#   'cheaper',
#   'option',
#   'coming',
#   'in',
#   'about',
#   'six',
#   'or',
#   'seven',
#   'dollars',
#   'per',
#   'book',
#   'ebook',
#   'sales',
#   'are',
#   'up',
#   'as',
#   'much',
#   'as',
#   'percent',
#   'for',
#   'many',
#   'of',
#   'the',
#   'major',
#   'houses',
#   'but',
#   'that',
#   'in',
#   'context',
#   'where',
#   'ebooks',
#   'are',
#   'still',
#   'representing',
#   'still',
#   'under',
#   'about',
#   'one',
#   'percent',
#   'of',
#   'total',
#   'book',
#   'sales'],
#  ['may',
#   'press',
#   'you',
#   'bit',
#   'about',
#   'some',
#   'of',
#   'these',
#   'new',
#   'technologies'],
#  ['sure'],
#  ['because',
#   'can',
#   'remember',
#   'time',
#   'when',
#   'people',
#   'thought',
#   'that',
#   'you',
#   'know',
#   'nothing',
#   'would',
#   'replace',
#   'the',
#   'newspaper',
#   'and',
#   'obviously',
#   'lot',
#   'of',
#   'people',
#   'have',
#   'found',
#   'some',
#   'kind',
#   'of',
#   'replacement',
#   'for',
#   'newspapers',
#   'online',
#   'and',
#   'through',
#   'other',
#   'media',
#   'and',
#   'then',
#   'you',
#   'know',
#   've',
#   'talked',
#   'to',
#   'recording',
#   'industry',
#   'executives',
#   'who',
#   've',
#   'said',
#   'we',
#   'love',
#   'to',
#   'get',
#   'out',
#   'of',
#   'the',
#   'hardware',
#   'business',
#   'you',
#   'know',
#   'all',
#   'the',
#   'making',
#   'cds',
#   'making',
#   'the',
#   'tamperproof',
#   'covers',
#   'now',
#   'as',
#   'don',
#   'have',
#   'to',
#   'tell',
#   'you',
#   'in',
#   'books',
#   'to',
#   'print',
#   'them',
#   'to',
#   'sell',
#   'them',
#   'is',
#   'expensive',
#   'and',
#   'speculative',
#   'can',
#   'books',
#   'really',
#   'expect',
#   'even',
#   'for',
#   'years',
#   'to',
#   'not',
#   'be',
#   'subject',
#   'to',
#   'technological',
#   'changes'],
#  ['the',
#   'software',
#   'analysis',
#   'all',
#   'of',
#   'those',
#   'human',
#   'factors',
#   'and',
#   'processes',
#   'them',
#   'with',
#   'algorithms',
#   'that',
#   'information',
#   'generally',
#   'won',
#   'help',
#   'right',
#   'there',
#   'during',
#   'that',
#   'call',
#   'but',
#   'schaffer',
#   'says',
#   'it',
#   'can',
#   'be',
#   'used',
#   'to',
#   'answer',
#   'important',
#   'questions',
#   'companies',
#   'may',
#   'have'],
#  ['what',
#   'kinds',
#   'of',
#   'situations',
#   'what',
#   'kind',
#   'of',
#   'topics',
#   'are',
#   'bringing',
#   'up',
#   'this',
#   'kind',
#   'of',
#   'level',
#   'of',
#   'emotion',
#   'and',
#   'it',
#   'could',
#   'go',
#   'down',
#   'to',
#   'the',
#   'soft',
#   'skills',
#   'or',
#   'particular',
#   'agents',
#   'that',
#   'seem',
#   'to',
#   'have',
#   'patterns',
#   'of',
#   'customers',
#   'becoming',
#   'more',
#   'emotional',
#   'or',
#   'it',
#   'could',
#   'come',
#   'to',
#   'broad',
#   'business',
#   'issues',
#   'that',
#   'where',
#   'you',
#   'can',
#   'notice',
#   'pattern',
#   'between',
#   'heighten',
#   'emotions',
#   'and',
#   'particular',
#   'product',
#   'or',
#   'service',
#   'or',
#   'geographic',
#   'area',
#   'or',
#   'some',
#   'other',
#   'very',
#   'important',
#   'business',
#   'component'],
#  ['phil',
#   'tschudy',
#   'is',
#   'from',
#   'cuna',
#   'mutual',
#   'financial',
#   'services',
#   'group',
#   'in',
#   'madison',
#   'wisconsin',
#   'that',
#   'processes',
#   'thousands',
#   'of',
#   'calls',
#   'day'],
#  ['he',
#   'says',
#   'his',
#   'company',
#   'has',
#   'been',
#   'trying',
#   'out',
#   'the',
#   'software',
#   'for',
#   'about',
#   'year',
#   'as',
#   'feedback',
#   'tool'],
#  ['this',
#   'is',
#   'an',
#   'opportunity',
#   'for',
#   'us',
#   'to',
#   'go',
#   'back',
#   'and',
#   'make',
#   'sure',
#   'that',
#   'we',
#   're',
#   'looking',
#   'for',
#   'trends',
#   'that',
#   'can',
#   'be',
#   'addressed',
#   'that',
#   'we',
#   'can',
#   'help',
#   'our',
#   'call',
#   'center',
#   'representatives',
#   'improve',
#   'the',
#   'services',
#   'they',
#   'deliver'],
#  ['and',
#   'think',
#   'ultimately',
#   'consumers',
#   'want',
#   'that',
#   'and',
#   'demands',
#   'are',
#   'higher',
#   'than',
#   'they',
#   'have',
#   'every',
#   'been',
#   'and',
#   'so',
#   'this',
#   'is',
#   'great',
#   'tool',
#   'for',
#   'us',
#   'to',
#   'really',
#   'understand',
#   'what',
#   'are',
#   'customers',
#   'want',
#   'and',
#   'then',
#   'deliver',
#   'on',
#   'that',
#   'on',
#   'those',
#   'expectations'],
#  ['this',
#   'idea',
#   'sounds',
#   'great',
#   'but',
#   'there',
#   'is',
#   'some',
#   'problems',
#   'big',
#   'companies',
#   'want',
#   'to',
#   'cut',
#   'costs',
#   'so',
#   'more',
#   'phone',
#   'support',
#   'has',
#   'been',
#   'outsourced',
#   'to',
#   'call',
#   'centers',
#   'overseas',
#   'but',
#   'the',
#   'issue',
#   'is',
#   'that',
#   'english',
#   'may',
#   'not',
#   'be',
#   'first',
#   'language',
#   'for',
#   'most',
#   'of',
#   'the',
#   'reps',
#   'answering',
#   'phones',
#   'and',
#   'if',
#   'communication',
#   'gap',
#   'grows',
#   'wider',
#   'another',
#   'automated',
#   'solution',
#   'probably',
#   'won',
#   'go',
#   'far',
#   'enough',
#   'to',
#   'comfort',
#   'the',
#   'outraged',
#   'and',
#   'unhappy',
#   'customer',
#   'for',
#   'npr',
#   'news',
#   'xeni',
#   'jardin'],
#  ['soundbite', 'of', 'music'],
#  ['this',
#   'is',
#   'talk',
#   'of',
#   'the',
#   'nation',
#   'science',
#   'friday',
#   'ira',
#   'flatow',
#   'we',
#   're',
#   'here',
#   'in',
#   'tucson',
#   'arizona',
#   'and',
#   'if',
#   'you',
#   've',
#   'ever',
#   'visited',
#   'this',
#   'part',
#   'of',
#   'the',
#   'country',
#   'you',
#   'know',
#   'it',
#   'can',
#   'get',
#   'really',
#   'hot',
#   'and',
#   'not',
#   'talking',
#   'about',
#   'the',
#   'weather',
#   'talking',
#   'about',
#   'the',
#   'food',
#   'from',
#   'jalapenos',
#   'to',
#   'anaheim',
#   'to',
#   'poblano',
#   'folks',
#   'in',
#   'this',
#   'part',
#   'of',
#   'that',
#   'world',
#   'have',
#   'been',
#   'spicing',
#   'their',
#   'food',
#   'with',
#   'chilies',
#   'for',
#   'centuries'],
#  ['but',
#   'something',
#   'learned',
#   'on',
#   'this',
#   'trip',
#   'out',
#   'west',
#   'is',
#   'that',
#   'chilies',
#   'don',
#   'just',
#   'make',
#   'food',
#   'hot',
#   'there',
#   'are',
#   'lots',
#   'of',
#   'mild',
#   'ones',
#   'too',
#   'that',
#   'are',
#   'used',
#   'in',
#   'cooking',
#   'and',
#   'chilies',
#   'have',
#   'non',
#   'food',
#   'uses',
#   'too',
#   'we',
#   'll',
#   'talk',
#   'about',
#   'all',
#   'the',
#   'uses',
#   'for',
#   'chilies',
#   'you',
#   'know',
#   'for',
#   'example',
#   'their',
#   'signature',
#   'chemical',
#   'compound',
#   'capsaicin'],
#  ['that',
#   'stuff',
#   'that',
#   'makes',
#   'them',
#   'hot',
#   'is',
#   'also',
#   'used',
#   'for',
#   'pain',
#   'reliever',
#   'see',
#   'your',
#   'shaking',
#   'your',
#   'head',
#   'you',
#   'knew',
#   'that',
#   'yes',
#   'and',
#   'their',
#   'color',
#   'is',
#   'used',
#   'in',
#   'cosmetics',
#   'with',
#   'lipsticks',
#   'did',
#   'you',
#   'know',
#   'that',
#   'too',
#   'well',
#   'well',
# ...
#   'the',
#   'th',
#   'century',
#   'he',
#   'kept',
#   'gossip',
#   'columnists',
#   'busy',
#   'for',
#   'decades'],
#  ['yes', 'go', 'ahead', 'please'],
#  ['john',
#   'horrigan',
#   'is',
#   'the',
#   'associate',
#   'director',
#   'for',
#   'research',
#   'at',
#   'the',
#   'pew',
#   'internet',
#   'and',
#   'american',
#   'life',
#   'project',
#   'in',
#   'washington',
#   'he',
#   'joins',
#   'us',
#   'today',
#   'by',
#   'phone',
#   'welcome',
#   'to',
#   'the',
#   'program',
#   'john'],
#  ['nice', 'to', 'be', 'with', 'you'],
#  ['thank',
#   'you',
#   'larry',
#   'peterson',
#   'is',
#   'professor',
#   'and',
#   'chair',
#   'of',
#   'the',
#   'department',
#   'of',
#   'computer',
#   'science',
#   'at',
#   'princeton',
#   'university',
#   'in',
#   'princeton',
#   'new',
#   'jersey',
#   'he',
#   'the',
#   'director',
#   'of',
#   'the',
#   'planetlab',
#   'consortium',
#   'an',
#   'experiment',
#   'into',
#   'new',
#   'networking',
#   'technologies',
#   'he',
#   'joins',
#   'us',
#   'from',
#   'the',
#   'studios',
#   'on',
#   'the',
#   'princeton',
#   'campus',
#   'welcome',
#   'to',
#   'science',
#   'friday'],
#  ['good', 'afternoon'],
#  ['let',
#   'me',
#   'ask',
#   'you',
#   'all',
#   'gentlemen',
#   'let',
#   'me',
#   'ask',
#   'you',
#   'first',
#   'larry',
#   'ten',
#   'years',
#   'from',
#   'now',
#   'what',
#   'will',
#   'the',
#   'internet',
#   'look',
#   'like',
#   'take',
#   'open',
#   'that',
#   'crystal',
#   'ball',
#   'for',
#   'us',
#   'can',
#   'you',
#   'look',
#   'into',
#   'it',
#   'and',
#   'tell',
#   'us',
#   'what',
#   'you',
#   'think',
#   'the',
#   'internet',
#   'will',
#   'look',
#   'like',
#   'what',
#   'it',
#   'should',
#   'look',
#   'like'],
#  ['well',
#   'what',
#   'hope',
#   'it',
#   'looks',
#   'like',
#   'is',
#   'it',
#   'place',
#   'that',
#   'you',
#   'can',
#   'securely',
#   'do',
#   'all',
#   'sorts',
#   'of',
#   'online',
#   'transactions',
#   'think',
#   'that',
#   'something',
#   'that',
#   'people',
#   'are',
#   'really',
#   'worried',
#   'about',
#   'today',
#   'between',
#   'the',
#   'various',
#   'fishing',
#   'and',
#   'hijacking',
#   'of',
#   'connections',
#   'and',
#   'so',
#   'on',
#   'that',
#   'we',
#   'may',
#   'in',
#   'fact',
#   'be',
#   'reaching',
#   'point',
#   'that',
#   'the',
#   'average',
#   'user',
#   'loses',
#   'trust',
#   'in',
#   'the',
#   'internet',
#   'and',
#   'that',
#   'clearly',
#   'something',
#   'we',
#   'have',
#   'to',
#   'pay',
#   'attention',
#   'to',
#   'over',
#   'the',
#   'next',
#   'years'],
#  ['mm',
#   'hmm',
#   'know',
#   'phil',
#   'zimmermann',
#   'who',
#   'one',
#   'of',
#   'the',
#   'gurus',
#   'of',
#   'security',
#   'on',
#   'the',
#   'internet',
#   'has',
#   'been',
#   'talking',
#   'about',
#   'the',
#   'hijacking',
#   'of',
#   'voice',
#   'material',
#   'people',
#   'talking',
#   'to',
#   'each',
#   'other',
#   'now',
#   'that',
#   'could',
#   'be',
#   'problem'],
#  ['absolutely'],
#  ['yeah'],
#  ['this',
#   'is',
#   'widespread',
#   'problem',
#   'it',
#   'not',
#   'just',
#   'from',
#   'the',
#   'obvious',
#   'that',
#   'you',
#   're',
#   'not',
#   'securely',
#   'logging',
#   'into',
#   'your',
#   'bank',
#   'but',
#   'online',
#   'content',
#   'is',
#   'under',
#   'attack',
#   'all',
#   'the',
#   'time',
#   'from',
#   'denial',
#   'of',
#   'service',
#   'attacks',
#   'and',
#   'so',
#   'on',
#   'so',
#   'it',
#   'clearly',
#   'an',
#   'issue',
#   'that',
#   'we',
#   'have',
#   'to',
#   'start',
#   'paying',
#   'attention',
#   'to'],
#  ['mm',
#   'hmm',
#   'tim',
#   'wu',
#   'what',
#   'do',
#   'you',
#   'think',
#   'the',
#   'internet',
#   'could',
#   'and',
#   'should',
#   'look',
#   'like',
#   'years',
#   'from',
#   'now'],
#  ['well',
#   'it',
#   'could',
#   'look',
#   'one',
#   'of',
#   'many',
#   'ways',
#   'think',
#   'there',
#   'basic',
#   'debate',
#   'that',
#   'you',
#   'mentioned',
#   'earlier',
#   'between',
#   'something',
#   'that',
#   'much',
#   'more',
#   'centralized',
#   'network',
#   'than',
#   'we',
#   'have',
#   'today',
#   'something',
#   'more',
#   'like',
#   'cable',
#   'television',
#   'and',
#   'another',
#   'vision',
#   'one',
#   'which',
#   'think',
#   'is',
#   'better',
#   'which',
#   'is',
#   'rather',
#   'like',
#   'the',
#   'internet',
#   'is',
#   'today',
#   'just',
#   'faster',
#   'and',
#   'capable',
#   'of',
#   'more',
#   'things'],
#  ['the',
#   'internet',
#   'today',
#   'is',
#   'very',
#   'decentralized',
#   'people',
#   'come',
#   'up',
#   'with',
#   'stuff',
#   'whether',
#   'it',
#   'on',
#   'youtube',
#   'or',
#   'whether',
#   'it',
#   'ebay',
#   'or',
#   'whether',
#   'it',
#   'you',
#   'know',
#   'people',
#   'blogs',
#   'and',
#   'hope',
#   'that',
#   'it',
#   'retains',
#   'its',
#   'character',
#   'as',
#   'decentralized',
#   'medium',
#   'that',
#   'basically',
#   'everyone',
#   'uses',
#   'that',
#   'just',
#   'has',
#   'lot',
#   'more',
#   'bandwidth',
#   'is',
#   'lot',
#   'faster',
#   'and',
#   'works',
#   'lot',
#   'better'],
#  ['do',
#   'we',
#   'have',
#   'to',
#   'build',
#   'new',
#   'backbone',
#   'to',
#   'the',
#   'internet'],
#  ['do',
#   'we',
#   'have',
#   'to',
#   'build',
#   'new',
#   'backbone',
#   'you',
#   'know',
#   'mean',
#   'the',
#   'new',
#   'actually',
#   'backbone',
#   'if',
#   'you',
#   're',
#   'interested',
#   'in',
#   'the',
#   'technical',
#   'side',
#   'backbone',
#   'isn',
#   'where',
#   'the',
#   'problem',
#   'is',
#   'there',
#   'huge',
#   'amount',
#   'of',
#   'capacity',
#   'back',
#   'in',
#   'the',
#   'companies',
#   'even',
#   'like',
#   'enron',
#   'built',
#   'massive',
#   'amounts',
#   'of',
#   'capacity',
#   'into',
#   'the',
#   'backbone'],
#  ['the',
#   'real',
#   'bottleneck',
#   'and',
#   'this',
#   'has',
#   'been',
#   'true',
#   'since',
#   'since',
#   'actually',
#   'about',
#   'is',
#   'the',
#   'pipes',
#   'and',
#   'the',
#   'wire',
#   'that',
#   'goes',
#   'to',
#   'people',
#   'homes',
#   'and',
#   'the',
#   'challenge',
#   'over',
#   'the',
#   'next',
#   'decade',
#   'is',
#   'whether',
#   'we',
#   'will',
#   'really',
#   'get',
#   'the',
#   'same',
#   'kind',
#   'of',
#   'speeds',
#   'on',
#   'the',
#   'backbone',
#   'in',
#   'the',
#   'last',
#   'mile',
#   'which',
#   'is',
#   'to',
#   'say',
#   'right',
#   'to',
#   'people',
#   'homes'],
#  ['right',
#   'now',
#   'we',
#   'have',
#   'the',
#   'same',
#   'networks',
#   'the',
#   'cable',
#   'and',
#   'the',
#   'telephone',
#   'networks',
#   'that',
#   'we',
#   've',
#   'had',
#   'since',
#   'the',
#   'you',
#   'know',
#   'they',
#   've',
#   'been',
#   'updated',
#   'bit',
#   'but',
#   'basically',
#   'it',
#   'the',
#   'same',
#   'old',
#   'stuff',
#   'and',
#   'that',
#   'the',
#   'big',
#   'question',
#   'over',
#   'the',
#   'next',
#   'years'],
#  ['and',
#   'would',
#   'add',
#   'that',
#   'there',
#   'are',
#   'great',
#   'incentives',
#   'to',
#   'upgrade',
#   'the',
#   'network',
#   'simple',
#   'because',
#   'that',
#   'what',
#   'users',
#   'want',
#   'when',
#   'we',
#   'look',
#   'at',
#   'our',
#   'surveys',
#   'at',
#   'the',
#   'pew',
#   'internet',
#   'project',
#   'most',
#   'people',
#   'who',
#   'are',
#   'signing',
#   'onto',
#   'broadband',
#   'and',
#   'now',
#   'today',
#   'percent',
#   'of',
#   'americans',
#   'have',
#   'high',
#   'speed',
#   'connections',
#   'at',
#   'home',
#   'sign',
#   'on',
#   'for',
#   'the',
#   'speed',
#   'they',
#   'don',
#   'tell',
#   'us',
#   'that',
#   'the',
#   'price',
#   'fell',
#   'and',
#   'decided',
#   'to',
#   'switch',
#   'the',
#   'longer',
#   'people',
#   'stay',
#   'online',
#   'the',
#   'more',
#   'they',
#   'want',
#   'to',
#   'do',
#   'online',
#   'and',
#   'their',
#   'demand',
#   'for',
#   'speed',
#   'increases',
#   'as',
#   'they',
#   'get',
#   'more',
#   'experience',
#   'on',
#   'the',
#   'internet'],
#  ['are',
#   'they',
#   'gonna',
#   'forget',
#   'about',
#   'speed',
#   'after',
#   'while',
#   'and',
#   'want',
#   'the',
#   'services',
#   'more',
#   'mean',
#   'will',
#   'speed',
#   'just',
#   'become',
#   'part',
#   'of',
#   'the',
#   'product',
#   'for',
#   'example',
#   'want',
#   'the',
#   'ability',
#   'to',
#   'watch',
#   'television',
#   'or',
#   'stream',
#   'video',
#   'or',
#   'do',
#   'these',
#   'kinds',
#   'of',
#   'high',
#   'bandwidth',
#   'things',
#   'that',
#   'they',
#   'don',
#   'normally',
#   'do',
#   'now',
#   'and',
#   'that',
#   'they',
#   're',
#   'seeing',
#   'other',
#   'people',
#   'doing',
#   'and',
#   'you',
#   'know',
#   'they',
#   're',
#   'we',
#   're',
#   'beginning',
#   'to',
#   'download',
#   'old',
#   'tv',
#   'shows',
#   'that',
#   'we',
#   'missed',
#   'the',
#   'night',
#   'before',
#   'on',
#   'the',
#   'internet',
#   'so',
#   'is',
#   'that',
#   'kind',
#   'of',
#   'thing',
#   'they',
#   're',
#   'gonna',
#   'worry',
#   'more',
#   'about',
#   'than',
#   'the',
#   'speed'],
#  ['well',
#   'think',
#   'they',
#   're',
#   'gonna',
#   'worry',
#   'about',
#   'both',
#   'people',
#   'like',
#   'to',
#   'do',
#   'those',
#   'entertainment',
#   'applications',
#   'online',
#   'but',
#   'one',
#   'of',
#   'the',
#   'real',
#   'markers',
#   'of',
#   'internet',
#   'user',
#   'behavior',
#   'and',
#   'it',
#   'fairly',
#   'common',
#   'behavior',
#   'along',
#   'across',
#   'broadband',
#   'internet',
#   'users',
#   'is',
#   'what',
#   'we',
#   'call',
#   'user',
#   'generated',
#   'content',
#   'people',
#   'like',
#   'the',
#   'speed',
#   'in',
#   'order',
#   'to',
#   'post',
#   'things',
#   'online',
#   'about',
#   'their',
#   'lives',
#   'about',
#   'what',
#   'they',
#   're',
#   'doing',
#   'they',
#   'like',
#   'to',
#   'post',
#   'online',
#   'their',
#   'own',
#   'creativity'],
#  ['now',
#   'some',
#   'of',
#   'that',
#   'stuff',
#   'is',
#   'not',
#   'gonna',
#   'be',
#   'widely',
#   'interesting',
#   'to',
#   'the',
#   'world',
#   'at',
#   'large',
#   'but',
#   'it',
#   'interesting',
#   'to',
#   'users',
#   'and',
#   'their',
#   'social',
#   'networks',
#   'so',
#   'they',
#   're',
#   'gonna',
#   'want',
#   'the',
#   'entertainment',
#   'services',
#   'but',
#   'they',
#   're',
#   'gonna',
#   'want',
#   'to',
#   'continue',
#   'to',
#   'have',
#   'an',
#   'internet',
#   'that',
#   'enables',
#   'them',
#   'to',
#   'express',
#   'themselves',
#   'online'],
#  ['mm', 'hmm'],
#  ['right', 'if', 'could', 'add', 'to', 'that', 'mean'],
#  ['sure'],
#  ['think',
#   'there',
#   'no',
#   'doubt',
#   'that',
#   'people',
#   'you',
#   'know',
#   'people',
#   'would',
#   'like',
#   'more',
#   'bandwidth',
#   'but',
#   'and',
#   'people',
#   'would',
#   'like',
#   'more',
#   'services',
#   'people',
#   'like',
#   'watching',
#   'videos',
#   'they',
#   'move',
#   'and',
#   'you',
#   'can',
#   'see',
#   'people',
#   'walking',
#   'around',
#   'but',
#   'the',
#   'question',
#   'is',
#   'who',
#   'provides',
#   'them'],
#  ['ll',
#   'jump',
#   'in',
#   'on',
#   'that',
#   'don',
#   'quite',
#   'see',
#   'it',
#   'as',
#   'threat',
#   'as',
#   'much',
#   'as',
#   'phenomenon',
#   'particularly',
#   'at',
#   'the',
#   'country',
#   'level',
#   'it',
#   'not',
#   'that',
#   'countries',
#   'won',
#   'be',
#   'able',
#   'to',
#   'talk',
#   'to',
#   'each',
#   'other',
#   'it',
#   'just',
#   'that',
#   'they',
#   'will',
#   'talk',
#   'to',
#   'each',
#   'other',
#   'less',
#   'you',
#   'know',
#   'when',
#   'the',
#   'internet',
#   'was',
#   'much',
#   'smaller',
#   'decade',
#   'ago',
#   'there',
#   'were',
#   'only',
#   'so',
#   'many',
#   'people',
#   'on',
#   'it',
#   'and',
#   'so',
#   'everybody',
#   'always',
#   'talked',
#   'to',
#   'each',
#   'other'],
#  ['gdp',
#   'and',
#   'mortality',
#   'and',
#   'education',
#   'are',
#   'the',
#   'sort',
#   'of',
#   'basic',
#   'statistics',
#   'for',
#   'how',
#   'the',
#   'nation',
#   'doing'],
#  ['and',
#   'there',
#   'basic',
#   'philosophical',
#   'divide',
#   'between',
#   'two',
#   'approaches',
#   'one',
#   'which',
#   'is',
#   'more',
#   'like',
#   'cable',
#   'which',
#   'is',
#   'basically',
#   'what',
#   'we',
#   've',
#   'had',
#   'since',
#   'the',
#   'which',
#   'is',
#   'centralized',
#   'entity',
#   'like',
#   'the',
#   'phone',
#   'company',
#   'or',
#   'the',
#   'cable',
#   'company',
#   'and',
#   'some',
#   'producers',
#   'create',
#   'it',
#   'or',
#   'what',
#   'was',
#   'just',
#   'referred',
#   'to',
#   'the',
#   'kind',
#   'of',
#   'world',
#   'where',
#   'people',
#   'just',
#   'throw',
#   'up',
#   'random',
#   'things',
#   'and',
#   'that',
#   'what',
#   'people',
#   'watch',
#   'and',
#   'how',
#   'you',
#   'build',
#   'the',
#   'network',
#   'how',
#   'the',
#   'network',
#   'gets',
#   'built',
#   'out',
#   'will',
#   'determine',
#   'what',
#   'kind',
#   'of',
#   'culture',
#   'prevails',
#   'something',
#   'more',
#   'like',
#   'what',
#   'the',
#   'internet',
#   'now',
#   'which',
#   'is',
#   'much',
#   'more',
#   'of',
#   'folky',
#   'kind',
#   'of',
#   'culture',
#   'where',
#   'people',
#   'watch',
#   'really',
#   'bad',
#   'quality',
#   'video',
#   'cause',
#   'they',
#   'think',
#   'it',
#   'funny',
#   'or',
#   'they',
#   'read',
#   'blogs',
#   'almost',
#   'as',
#   'much',
#   'as',
#   'they',
#   'll',
#   'read',
#   'the',
#   'new',
#   'york',
#   'times',
#   'or',
#   'something',
#   'which',
#   'is',
#   'more',
#   'like',
#   'the',
#   'old',
#   'media',
#   'world',
#   'where',
#   'things',
#   'like',
#   'video',
#   'are',
#   'dominated',
#   'by',
#   'centralized',
#   'decision',
#   'makers',
#   'that',
#   'the',
#   'philosophical',
#   'battle',
#   'behind',
#   'net',
#   'neutrality',
#   'and',
#   'lot',
#   'of',
#   'other',
#   'stuff',
#   'going',
#   'on',
#   'right',
#   'now'],
#  ['larry', 'peterson'],
#  ['just',
#   'like',
#   'to',
#   'add',
#   'that',
#   'of',
#   'course',
#   'speed',
#   'is',
#   'always',
#   'going',
#   'to',
#   'be',
#   'an',
#   'issue',
#   'and',
#   'users',
#   'are',
#   'certainly',
#   'going',
#   'to',
#   'demand',
#   'more',
#   'services',
#   'from',
#   'the',
#   'network',
#   'but',
#   'there',
#   'are',
#   'going',
#   'to',
#   'be',
#   'issues',
#   'of',
#   'ease',
#   'of',
#   'use',
#   'of',
#   'trust',
#   'of',
#   'going',
#   'to',
#   'want',
#   'to',
#   'take',
#   'the',
#   'internet',
#   'with',
#   'me',
#   'wherever',
#   'go',
#   'that',
#   'always',
#   'connected',
#   'always',
#   'access',
#   'to',
#   'my',
#   'data',
#   'and',
#   'so',
#   'on'],
#  ['these',
#   'of',
#   'course',
#   'are',
#   'services',
#   'but',
#   'again',
#   'get',
#   'back',
#   'to',
#   'the',
#   'issue',
#   'of',
#   'trust',
#   'and',
#   'that',
#   'going',
#   'to',
#   'become',
#   'very',
#   'significant',
#   'aspect',
#   'of',
#   'the',
#   'consumer',
#   'view',
#   'of',
#   'the',
#   'internet'],
#  ['go', 'ahead'],
#  ['sorry', 'can', 'step', 'in'],
#  ['sure'],
#  ['don',
#   'completely',
#   'disagree',
#   'with',
#   'that',
#   'but',
#   'want',
#   'to',
#   'disagree',
#   'little',
#   'bit',
#   'people',
#   'have',
#   'been',
#   'saying',
#   'since',
#   'the',
#   'that',
#   'so',
#   'many',
#   'things',
#   'wouldn',
#   'happen',
#   'on',
#   'the',
#   'internet',
#   'because',
#   'no',
#   'one',
#   'trusts',
#   'the',
#   'internet',
#   'pierre',
#   'omidyar',
#   'who',
#   'founded',
#   'ebay',
#   'his',
#   'whole',
#   'founding',
#   'principle',
#   'was',
#   'that',
#   'you',
#   'know',
#   'people',
#   'trust',
#   'each',
#   'other',
#   'and',
#   'ebay',
#   'has',
#   'never',
#   'been',
#   'all',
#   'that',
#   'secure',
#   'but',
#   'it',
#   'managed',
#   'to',
#   'be',
#   'successful',
#   'nonetheless'],
#  ['and',
#   'it',
#   'is',
#   'sort',
#   'of',
#   'surprising',
#   'how',
#   'many',
#   'things',
#   'you',
#   'know',
#   'how',
#   'secure',
#   'the',
#   'blogs',
#   'need',
#   'to',
#   'be',
#   'how',
#   'much',
#   'do',
#   'you',
#   'have',
#   'to',
#   'trust',
#   'them',
#   'think',
#   'there',
#   'been',
#   'bit',
#   'of',
#   'surprise',
#   'over',
#   'the',
#   'last',
#   'decade',
#   'of',
#   'how',
#   'many',
#   'things',
#   'have',
#   'happened',
#   'on',
#   'the',
#   'internet',
#   'even',
#   'though',
#   'it',
#   'not',
#   'as',
#   'secure',
#   'as',
#   'some',
#   'people',
#   'might',
#   'like',
#   'think',
#   'that',
#   'been',
#   'bit',
#   'of',
#   'surprise',
#   'to',
#   'people'],
#  ['think', 'lot', 'agree', 'with', 'that'],
#  ['yeah', 'yeah', 'yeah'],
#  ['so',
#   'it',
#   'certainly',
#   'the',
#   'case',
#   'that',
#   'the',
#   'internet',
#   'has',
#   'just',
#   'grown',
#   'beyond',
#   'expectations',
#   'and',
#   'people',
#   'are',
#   'depending',
#   'on',
#   'it',
#   'despite',
#   'all',
#   'the',
#   'security',
#   'risks',
#   'that',
#   'are',
#   'there',
#   'but',
#   'on',
#   'the',
#   'other',
#   'hand',
#   'what',
#   'see',
#   'happening',
#   'is',
#   'what',
#   'would',
#   'call',
#   'the',
#   'internet',
#   'fragmenting',
#   'into',
#   'gated',
#   'communities'],
#  ['and',
#   'this',
#   'is',
#   'almost',
#   'like',
#   'the',
#   'neutrality',
#   'aspect',
#   'of',
#   'the',
#   'issue',
#   'that',
#   'there',
#   'are',
#   'places',
#   'you',
#   'just',
#   'can',
#   'get',
#   'to',
#   'and',
#   'the',
#   'universal',
#   'connectivity',
#   'of',
#   'the',
#   'original',
#   'internet',
#   'is',
#   'deteriorating',
#   'because',
#   'of',
#   'lack',
#   'of',
#   'security',
#   'built',
#   'into',
#   'the',
#   'internet',
#   'your',
#   'only',
#   'recourse',
#   'is',
#   'to',
#   'throw',
#   'up',
#   'all',
#   'sorts',
#   'of',
#   'protections',
#   'that',
#   'are',
#   'extremely',
#   'suspicious',
#   'of',
#   'every',
#   'bit',
#   'of',
#   'traffic',
#   'that',
#   'happens',
#   'to',
#   'fly',
#   'by']]

# %%
model = gensim.models.Word2Vec(utterances, window=10, min_count=2, workers=10)
model

# %%
model.wv.key_to_index
# Out:
# {'the': 0,
#  'and': 1,
#  'of': 2,
#  'to': 3,
#  'that': 4,
#  'in': 5,
#  'you': 6,
#  'it': 7,
#  'is': 8,
#  'they': 9,
#  'we': 10,
#  'for': 11,
#  'this': 12,
#  'on': 13,
#  'are': 14,
#  'was': 15,
#  'have': 16,
#  'he': 17,
#  'so': 18,
#  'be': 19,
#  'there': 20,
#  'with': 21,
#  'but': 22,
#  'know': 23,
#  'what': 24,
#  'as': 25,
#  'not': 26,
#  'about': 27,
#  're': 28,
#  'do': 29,
#  'think': 30,
#  'or': 31,
#  'who': 32,
#  'people': 33,
#  'at': 34,
#  'from': 35,
#  'can': 36,
#  'just': 37,
#  'like': 38,
#  'very': 39,
#  'us': 40,
#  'one': 41,
#  'if': 42,
#  'well': 43,
#  'has': 44,
#  'some': 45,
#  'their': 46,
#  'an': 47,
#  'all': 48,
#  'when': 49,
#  'much': 50,
#  'these': 51,
#  'by': 52,
#  'his': 53,
#  'them': 54,
#  'more': 55,
#  'out': 56,
#  'how': 57,
#  'because': 58,
#  'would': 59,
#  'don': 60,
#  'now': 61,
#  'really': 62,
#  'right': 63,
#  'been': 64,
#  'talk': 65,
#  'here': 66,
#  'get': 67,
#  'time': 68,
#  'had': 69,
#  'case': 70,
#  'public': 71,
#  'other': 72,
#  'npr': 73,
#  'up': 74,
#  'our': 75,
#  'your': 76,
#  'were': 77,
#  'see': 78,
#  'said': 79,
#  'those': 80,
#  'did': 81,
#  'will': 82,
#  've': 83,
#  'going': 84,
#  'go': 85,
#  'where': 86,
#  'my': 87,
#  'she': 88,
#  'chili': 89,
#  'which': 90,
#  'new': 91,
#  'also': 92,
#  'years': 93,
#  'court': 94,
#  'many': 95,
#  'then': 96,
#  'today': 97,
#  'president': 98,
#  'lot': 99,
#  'say': 100,
#  'back': 101,
#  'into': 102,
#  'over': 103,
#  'me': 104,
#  'no': 105,
#  'good': 106,
#  'let': 107,
#  'kind': 108,
#  'even': 109,
#  'than': 110,
#  'thanks': 111,
#  'two': 112,
#  'year': 113,
#  'yeah': 114,
#  'want': 115,
#  'things': 116,
#  'internet': 117,
#  'thank': 118,
#  'make': 119,
#  'll': 120,
#  'look': 121,
#  'life': 122,
#  'could': 123,
#  'chicago': 124,
#  'news': 125,
#  'why': 126,
#  'only': 127,
#  'first': 128,
#  'way': 129,
#  'may': 130,
#  'should': 131,
#  'ph': 132,
#  'after': 133,
#  'got': 134,
#  'still': 135,
#  'any': 136,
#  'soundbite': 137,
#  'point': 138,
#  'hot': 139,
#  'talking': 140,
#  'call': 141,
#  'three': 142,
#  'her': 143,
#  'sure': 144,
#  'day': 145,
#  'little': 146,
#  'police': 147,
#  'actually': 148,
#  'chilies': 149,
#  'states': 150,
#  'different': 151,
#  'sort': 152,
#  'part': 153,
#  'something': 154,
#  'nation': 155,
#  'yes': 156,
#  'next': 157,
#  'take': 158,
#  'didn': 159,
#  'most': 160,
#  'mean': 161,
#  'cases': 162,
#  'down': 163,
#  'him': 164,
#  'question': 165,
#  'great': 166,
#  'book': 167,
#  'defenders': 168,
#  'too': 169,
#  'week': 170,
#  'both': 171,
#  'suicide': 172,
#  'another': 173,
#  'same': 174,
#  'last': 175,
#  'without': 176,
#  'long': 177,
#  'does': 178,
#  'country': 179,
#  'story': 180,
#  'person': 181,
#  'says': 182,
#  'through': 183,
#  'need': 184,
#  'government': 185,
#  'between': 186,
#  'music': 187,
#  'org': 188,
#  'ago': 189,
#  'work': 190,
#  'north': 191,
#  'state': 192,
#  'probably': 193,
#  'hi': 194,
#  'tour': 195,
#  'high': 196,
#  'hear': 197,
#  'certainly': 198,
#  'defender': 199,
#  'whether': 200,
#  'before': 201,
#  'school': 202,
#  'world': 203,
#  'arizona': 204,
#  'every': 205,
#  'around': 206,
#  'prison': 207,
#  'though': 208,
#  'law': 209,
#  'office': 210,
#  'tell': 211,
#  'feel': 212,
#  'course': 213,
#  'murder': 214,
#  'thing': 215,
#  'song': 216,
#  'doing': 217,
#  'put': 218,
#  'old': 219,
#  'vote': 220,
#  'find': 221,
#  'called': 222,
#  'system': 223,
#  'difficult': 224,
#  'west': 225,
#  'issue': 226,
#  'phone': 227,
#  'own': 228,
#  'ed': 229,
#  'care': 230,
#  'sentence': 231,
#  'came': 232,
#  'de': 233,
#  'won': 234,
#  'each': 235,
#  'program': 236,
#  'justice': 237,
#  'american': 238,
#  'neal': 239,
#  'science': 240,
#  'big': 241,
#  'war': 242,
#  'being': 243,
#  'against': 244,
#  'again': 245,
#  'family': 246,
#  'house': 247,
#  'trump': 248,
#  'issues': 249,
#  'flavor': 250,
#  'crime': 251,
#  'parole': 252,
#  'juveniles': 253,
#  'white': 254,
#  'general': 255,
#  'industry': 256,
#  'heat': 257,
#  'number': 258,
#  'party': 259,
#  'gary': 260,
#  'democrats': 261,
#  'supreme': 262,
#  'made': 263,
#  'important': 264,
#  'man': 265,
#  'use': 266,
#  'four': 267,
#  'sometimes': 268,
#  'goes': 269,
#  'percent': 270,
#  'real': 271,
#  'death': 272,
#  'france': 273,
#  'its': 274,
#  'coming': 275,
#  'while': 276,
#  'kevin': 277,
#  'end': 278,
#  'davis': 279,
#  'under': 280,
#  'love': 281,
#  'united': 282,
#  'understand': 283,
#  'found': 284,
#  'basically': 285,
#  'almost': 286,
#  'always': 287,
#  'korea': 288,
#  'bit': 289,
#  'south': 290,
#  'used': 291,
#  'come': 292,
#  'interesting': 293,
#  'particular': 294,
#  'often': 295,
#  'doesn': 296,
#  'maybe': 297,
#  'give': 298,
#  'far': 299,
#  'york': 300,
#  'food': 301,
#  'working': 302,
#  'job': 303,
#  'told': 304,
#  'federal': 305,
#  'five': 306,
#  'report': 307,
#  'pepper': 308,
#  'mexico': 309,
#  'days': 310,
#  'able': 311,
#  'health': 312,
#  'team': 313,
#  'woman': 314,
#  'trying': 315,
#  'political': 316,
#  'off': 317,
#  'media': 318,
#  'fact': 319,
#  'ahead': 320,
#  'email': 321,
#  'university': 322,
#  'wants': 323,
#  'held': 324,
#  'night': 325,
#  'might': 326,
#  'hurricane': 327,
#  'process': 328,
#  'went': 329,
#  'watch': 330,
#  'opinion': 331,
#  'terms': 332,
#  'spent': 333,
#  'company': 334,
#  'saying': 335,
#  'looking': 336,
#  'client': 337,
#  'seed': 338,
#  'tucson': 339,
#  'phil': 340,
#  'marijane': 341,
#  'joins': 342,
#  'water': 343,
#  'human': 344,
#  'absolutely': 345,
#  'exactly': 346,
#  'group': 347,
#  'times': 348,
#  'sense': 349,
#  'information': 350,
#  'appreciate': 351,
#  'online': 352,
#  'true': 353,
#  'join': 354,
#  'wild': 355,
#  'later': 356,
#  'name': 357,
#  'action': 358,
#  'bad': 359,
#  'obviously': 360,
#  'john': 361,
#  'seeing': 362,
#  'keep': 363,
#  'believe': 364,
#  'done': 365,
#  'matter': 366,
#  'kansas': 367,
#  'pay': 368,
#  'deal': 369,
#  'second': 370,
#  'problem': 371,
#  'network': 372,
#  'having': 373,
#  'hand': 374,
#  'best': 375,
#  'committed': 376,
#  'race': 377,
#  'clients': 378,
#  'unintelligible': 379,
#  'line': 380,
#  'friday': 381,
#  'green': 382,
#  'ask': 383,
#  'wrote': 384,
#  'congress': 385,
#  'grow': 386,
#  'mm': 387,
#  'example': 388,
#  'constitution': 389,
#  'tv': 390,
#  'leader': 391,
#  'scoville': 392,
#  'together': 393,
#  'money': 394,
#  'better': 395,
#  'needs': 396,
#  'until': 397,
#  'along': 398,
#  'making': 399,
#  'defending': 400,
#  'clear': 401,
#  'less': 402,
#  'history': 403,
#  'felt': 404,
#  'type': 405,
#  'washington': 406,
#  'black': 407,
#  'few': 408,
#  'welcome': 409,
#  'crimes': 410,
#  'young': 411,
#  'release': 412,
#  'happened': 413,
#  'criminal': 414,
#  'gone': 415,
#  'plant': 416,
#  'show': 417,
#  'jeff': 418,
#  'since': 419,
#  'never': 420,
#  'place': 421,
#  'bike': 422,
#  'turn': 423,
#  'calls': 424,
#  'thought': 425,
#  'trial': 426,
#  'brazil': 427,
#  'treatment': 428,
#  'individuals': 429,
#  'conversation': 430,
#  'involved': 431,
#  'judge': 432,
#  'attorney': 433,
#  'officer': 434,
#  'read': 435,
#  'stay': 436,
#  'david': 437,
#  'everybody': 438,
#  'ways': 439,
#  'recording': 440,
#  'questions': 441,
#  'decision': 442,
#  'wanted': 443,
#  'plants': 444,
#  'broad': 445,
#  'wall': 446,
#  'someone': 447,
#  'victim': 448,
#  'campus': 449,
#  'try': 450,
#  'americans': 451,
#  'front': 452,
#  'hard': 453,
#  'moon': 454,
#  'seems': 455,
#  'cook': 456,
#  'morning': 457,
#  'term': 458,
#  'stuff': 459,
#  'during': 460,
#  'continue': 461,
#  'department': 462,
#  'california': 463,
#  'free': 464,
#  'getting': 465,
#  'oh': 466,
#  'home': 467,
#  'speed': 468,
#  'gets': 469,
#  'left': 470,
#  'stephen': 471,
#  'seen': 472,
#  'released': 473,
#  'audience': 474,
#  'listening': 475,
#  'side': 476,
#  'laughter': 477,
#  'cuba': 478,
#  'children': 479,
#  'wouldn': 480,
#  'set': 481,
#  'million': 482,
#  'reason': 483,
#  'ever': 484,
#  'florida': 485,
#  'live': 486,
#  'several': 487,
#  'earlier': 488,
#  'county': 489,
#  'clearly': 490,
#  'capital': 491,
#  'january': 492,
#  'others': 493,
#  'details': 494,
#  'records': 495,
#  'republicans': 496,
#  'full': 497,
#  'jersey': 498,
#  'defense': 499,
#  'help': 500,
#  'individual': 501,
#  'calling': 502,
#  'attention': 503,
#  'riders': 504,
#  'away': 505,
#  'enough': 506,
#  'iraq': 507,
#  'oil': 508,
#  'kinds': 509,
#  'guys': 510,
#  'hello': 511,
#  'start': 512,
#  'african': 513,
#  'using': 514,
#  'typically': 515,
#  'everyday': 516,
#  'win': 517,
#  'cost': 518,
#  'himself': 519,
#  'charged': 520,
#  'yet': 521,
#  'service': 522,
#  'cops': 523,
#  'role': 524,
#  'suspect': 525,
#  'eight': 526,
#  'possibility': 527,
#  'victims': 528,
#  'available': 529,
#  'least': 530,
#  'level': 531,
#  'face': 532,
#  'summit': 533,
#  'project': 534,
#  'talked': 535,
#  'mcallister': 536,
#  'fun': 537,
#  'cooke': 538,
#  'sam': 539,
#  'kids': 540,
#  'books': 541,
#  'given': 542,
#  'limited': 543,
#  'mentioned': 544,
#  'election': 545,
#  'evidence': 546,
#  'minutes': 547,
#  'punishment': 548,
#  'conan': 549,
#  'hope': 550,
#  'huge': 551,
#  'ready': 552,
#  'beyond': 553,
#  'loren': 554,
#  'considered': 555,
#  'students': 556,
#  'behind': 557,
#  'pretty': 558,
#  'dangerous': 559,
#  'gave': 560,
#  'comes': 561,
#  'anything': 562,
#  'officers': 563,
#  'curry': 564,
#  'amount': 565,
#  'video': 566,
#  'watching': 567,
#  'agree': 568,
#  'former': 569,
#  'data': 570,
#  'seven': 571,
#  'peppers': 572,
#  'weekend': 573,
#  'cell': 574,
#  'head': 575,
#  'makes': 576,
#  'non': 577,
#  'chilis': 578,
#  'seem': 579,
#  'couple': 580,
#  'national': 581,
#  'isn': 582,
#  'member': 583,
#  'across': 584,
#  'ok': 585,
#  'tea': 586,
#  'large': 587,
#  'lost': 588,
#  'lives': 589,
#  'worked': 590,
#  'area': 591,
#  'mauer': 592,
#  'happens': 593,
#  'season': 594,
#  'took': 595,
#  'penalty': 596,
#  'sentences': 597,
#  'hit': 598,
#  'okay': 599,
#  'oliver': 600,
#  'scott': 601,
#  'capacity': 602,
#  'hurricanes': 603,
#  'bye': 604,
#  'college': 605,
#  'pictures': 606,
#  'follow': 607,
#  'city': 608,
#  'knew': 609,
#  'hundreds': 610,
#  'defend': 611,
#  'wasn': 612,
#  'mild': 613,
#  'breeding': 614,
#  'quote': 615,
#  'homicides': 616,
#  'sentenced': 617,
#  'sales': 618,
#  'range': 619,
#  'gonna': 620,
#  'flatow': 621,
#  'ira': 622,
#  'definitely': 623,
#  'sensitive': 624,
#  'professor': 625,
#  'hearing': 626,
#  'weeks': 627,
#  'warrant': 628,
#  'task': 629,
#  'decisions': 630,
#  'guess': 631,
#  'ombudsman': 632,
#  'yesterday': 633,
#  'placek': 634,
#  'aloysius': 635,
#  'kept': 636,
#  'necessary': 637,
#  'past': 638,
#  'speech': 639,
#  'bill': 640,
#  'hey': 641,
#  'cellphone': 642,
#  'brought': 643,
#  'desert': 644,
#  'top': 645,
#  'research': 646,
#  'nabhan': 647,
#  'such': 648,
#  'campaign': 649,
#  'birds': 650,
#  'affected': 651,
#  'saw': 652,
#  'stories': 653,
#  'force': 654,
#  'power': 655,
#  'order': 656,
#  'savage': 657,
#  'texas': 658,
#  'context': 659,
#  'compounds': 660,
#  'majority': 661,
#  'content': 662,
#  'wife': 663,
#  'press': 664,
#  'anybody': 665,
#  'private': 666,
#  'chief': 667,
#  'civil': 668,
#  'happy': 669,
#  'particularly': 670,
#  'asked': 671,
#  'change': 672,
#  'races': 673,
#  'whole': 674,
#  'either': 675,
#  'spicy': 676,
#  'services': 677,
#  'move': 678,
#  'support': 679,
#  'problems': 680,
#  'car': 681,
#  'meeting': 682,
#  'spoke': 683,
#  'rider': 684,
#  'christian': 685,
#  'hour': 686,
#  'argument': 687,
#  'idea': 688,
#  'administration': 689,
#  'represent': 690,
#  'view': 691,
#  'become': 692,
#  'sunni': 693,
#  'quite': 694,
#  'means': 695,
#  'anywhere': 696,
#  'klein': 697,
#  'lance': 698,
#  'military': 699,
#  'current': 700,
#  'minority': 701,
#  'battle': 702,
#  'juvenile': 703,
#  'miles': 704,
#  'built': 705,
#  'anyone': 706,
#  'reporters': 707,
#  'small': 708,
#  'following': 709,
#  'distance': 710,
#  'sides': 711,
#  'myself': 712,
#  'especially': 713,
#  'mountains': 714,
#  'overall': 715,
#  'programs': 716,
#  'jae': 717,
#  'ruling': 718,
#  'talks': 719,
#  'marc': 720,
#  'filed': 721,
#  'backbone': 722,
#  'kennedy': 723,
#  'challenging': 724,
#  'play': 725,
#  'thousands': 726,
#  'third': 727,
#  'strike': 728,
#  'democratic': 729,
#  'enforcement': 730,
#  'men': 731,
#  'republican': 732,
#  'population': 733,
#  'guest': 734,
#  'inside': 735,
#  'newspapers': 736,
#  'air': 737,
#  'cuban': 738,
#  'describing': 739,
#  'storm': 740,
#  'killed': 741,
#  'longer': 742,
#  'recently': 743,
#  'named': 744,
#  'emanuel': 745,
#  'activity': 746,
#  'business': 747,
#  'newscast': 748,
#  'price': 749,
#  'energy': 750,
#  'moment': 751,
#  'answer': 752,
#  'companies': 753,
#  'shouldn': 754,
#  'center': 755,
#  'higher': 756,
#  'operation': 757,
#  'friends': 758,
#  'accused': 759,
#  'jean': 760,
#  'homes': 761,
#  'hold': 762,
#  'mooney': 763,
#  'record': 764,
#  'glen': 765,
#  'write': 766,
#  'body': 767,
#  'involving': 768,
#  'sexual': 769,
#  'due': 770,
#  'compassion': 771,
#  'rather': 772,
#  'somebody': 773,
#  'correct': 774,
#  'happen': 775,
#  'reports': 776,
#  'basic': 777,
#  'community': 778,
#  'damned': 779,
#  'lisa': 780,
#  'theme': 781,
#  'ike': 782,
#  'television': 783,
#  'successful': 784,
#  'reserve': 785,
#  'chance': 786,
#  'everything': 787,
#  'killing': 788,
#  'carpenter': 789,
#  'please': 790,
#  'seeds': 791,
#  'outside': 792,
#  'digital': 793,
#  'location': 794,
#  'social': 795,
#  'ones': 796,
#  'age': 797,
#  'species': 798,
#  'search': 799,
#  'shot': 800,
#  'conditions': 801,
#  'student': 802,
#  'hmm': 803,
#  'afternoon': 804,
#  'uses': 805,
#  'genes': 806,
#  'whatever': 807,
#  'samina': 808,
#  'units': 809,
#  'nature': 810,
#  'blocks': 811,
#  'share': 812,
#  'six': 813,
#  'schumer': 814,
#  'ohio': 815,
#  'significant': 816,
#  'senate': 817,
#  'certain': 818,
#  'brief': 819,
#  'archived': 820,
#  'sentencing': 821,
#  'magazine': 822,
#  'director': 823,
#  'aren': 824,
#  'complaint': 825,
#  'rights': 826,
#  'event': 827,
#  'leave': 828,
#  'natural': 829,
#  'mother': 830,
#  'amendment': 831,
#  'begin': 832,
#  'bicycling': 833,
#  'serving': 834,
#  'heard': 835,
#  'agreed': 836,
#  'boy': 837,
#  'commitment': 838,
#  'fired': 839,
#  'editor': 840,
#  'counsel': 841,
#  'complete': 842,
#  'petition': 843,
#  'unusual': 844,
#  'reach': 845,
#  'percentage': 846,
#  'resources': 847,
#  'minors': 848,
#  'decided': 849,
#  'joined': 850,
#  'bring': 851,
#  'changed': 852,
#  'average': 853,
#  'provide': 854,
#  'amazing': 855,
#  'raise': 856,
#  'powers': 857,
#  'close': 858,
#  'regulate': 859,
#  'track': 860,
#  'step': 861,
#  'coverage': 862,
#  'must': 863,
#  'category': 864,
#  'debate': 865,
#  'weren': 866,
#  'movement': 867,
#  'remember': 868,
#  'potential': 869,
#  'eighth': 870,
#  'position': 871,
#  'oftentimes': 872,
#  'nine': 873,
#  'cyclists': 874,
#  'itself': 875,
#  'representing': 876,
#  'unpopular': 877,
#  'violent': 878,
#  'anaheim': 879,
#  'reading': 880,
#  'table': 881,
#  'subject': 882,
#  'changes': 883,
#  'sitting': 884,
#  'control': 885,
#  'belt': 886,
#  'turns': 887,
#  'varieties': 888,
#  'hm': 889,
#  'likely': 890,
#  'storms': 891,
#  'worst': 892,
#  'fairly': 893,
#  'guy': 894,
#  'cut': 895,
#  'author': 896,
#  'fully': 897,
#  'racing': 898,
#  'buildings': 899,
#  'shiites': 900,
#  'sunnis': 901,
#  'favor': 902,
#  'within': 903,
#  'son': 904,
#  'near': 905,
#  'damage': 906,
#  'officials': 907,
#  'sign': 908,
#  'street': 909,
#  'deborah': 910,
#  'lines': 911,
#  'kim': 912,
#  'perception': 913,
#  'victoria': 914,
#  'function': 915,
#  'self': 916,
#  'elevation': 917,
#  'daniel': 918,
#  'jail': 919,
#  'placenta': 920,
#  'behavior': 921,
#  'shepard': 922,
#  'joe': 923,
#  'local': 924,
#  'mike': 925,
#  'prosecutors': 926,
#  'experience': 927,
#  'store': 928,
#  'palfrey': 929,
#  'effort': 930,
#  'official': 931,
#  'am': 932,
#  'received': 933,
#  'missing': 934,
#  'instead': 935,
#  'ought': 936,
#  'democrat': 937,
#  'word': 938,
#  'elite': 939,
#  'break': 940,
#  'child': 941,
#  'umass': 942,
#  'growing': 943,
#  'fine': 944,
#  'run': 945,
#  'lawyer': 946,
#  'personal': 947,
#  'daley': 948,
#  'mayor': 949,
#  'cable': 950,
#  'legal': 951,
#  'dartmouth': 952,
#  'act': 953,
#  'moved': 954,
#  'baraka': 955,
#  'living': 956,
#  'essentially': 957,
#  'cd': 958,
#  'voice': 959,
#  'trust': 960,
#  'mail': 961,
#  'poor': 962,
#  'paying': 963,
#  'convicted': 964,
#  'janet': 965,
#  'secure': 966,
#  'arrested': 967,
#  'husband': 968,
#  'father': 969,
#  'vcu': 970,
#  'studios': 971,
#  'aids': 972,
#  'taking': 973,
#  'herself': 974,
#  'exchanges': 975,
#  'spitzer': 976,
#  'bigger': 977,
#  'mr': 978,
#  'temer': 979,
#  'user': 980,
#  'unless': 981,
#  'caller': 982,
#  'anna': 983,
#  'ballot': 984,
#  'reported': 985,
#  'necessarily': 986,
#  'senator': 987,
#  'crossing': 988,
#  'scale': 989,
#  'prices': 990,
#  'numbers': 991,
#  'listeners': 992,
#  'post': 993,
#  'nothing': 994,
#  'realize': 995,
#  'blog': 996,
#  'technologies': 997,
#  'picture': 998,
#  'per': 999,
#  ...}

# %%
model = gensim.models.Word2Vec(utterances, window=10, min_count=2, workers=10)

# %%
model.wv["war"].size
# Out:
# 100

# %%
w1 = ["war"]
model.wv.most_similar (positive=w1, topn=6)
# Out:
# [('us', 0.9994051456451416),
#  ('into', 0.9993998408317566),
#  ('with', 0.9993917346000671),
#  ('time', 0.9993862509727478),
#  ('that', 0.9993810653686523),
#  ('new', 0.9993647933006287)]

# %% [markdown]
# ### Some issues with the embeddings
#
# The models learn what's in the data:
#
# 1. Data may contain errors, biases, and inaccuracies
#
# 2. The similarity may not always be intuitive
#
# 3. The results will contain inaccuracies

# %%
utterances = list(read_input("./media/npr_100000_utterances.csv"))
model = gensim.models.Word2Vec(utterances, window=10, min_count=2, workers=10)
model

# %%
w1 = ["peace"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('hamas', 0.7439557909965515),
#  ('israel', 0.7426904439926147),
#  ('diplomatic', 0.7363422513008118),
#  ('palestinian', 0.7238703966140747),
#  ('resolution', 0.7224636077880859),
#  ('negotiations', 0.7209641337394714)]

# %%
w1 = ["france"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('britain', 0.8055888414382935),
#  ('paris', 0.8050899505615234),
#  ('jordan', 0.7818824052810669),
#  ('kenya', 0.770249605178833),
#  ('berlin', 0.7641852498054504),
#  ('georgia', 0.75344318151474)]

# %%
w1 = ["clean"]
model.wv.most_similar (positive=w1,topn=6)
# Out:
# [('wind', 0.7188198566436768),
#  ('speed', 0.6728765964508057),
#  ('coal', 0.6722075939178467),
#  ('radioactive', 0.6681318283081055),
#  ('prop', 0.6629115343093872),
#  ('carbon', 0.66191565990448)]

# %% [markdown]
# ### Facebook's FastText
# ```FastText is an open-source, free, lightweight library that allows users to learn text representations and text classifiers. It works on standard, generic hardware. Models can later be reduced in size to even fit on mobile devices.```

# %% [markdown]
# ![](https://www.dropbox.com/s/i74guibnv5mxx2h/fasttext.png?dl=1)
#
# https://fasttext.cc/

# %%
# !wget https://dl.fbaipublicfiles.com/fasttext/vectors-english/wiki-news-300d-1M.vec.zip
# Out:
# --2023-10-24 08:58:21--  https://dl.fbaipublicfiles.com/fasttext/vectors-english/wiki-news-300d-1M.vec.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 2600:9000:201d:d800:13:6e38:acc0:93a1, 2600:9000:201d:5600:13:6e38:acc0:93a1, 2600:9000:201d:4200:13:6e38:acc0:93a1, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|2600:9000:201d:d800:13:6e38:acc0:93a1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 681808098 (650M) [application/zip]
# Saving to: ‘wiki-news-300d-1M.vec.zip’
#
# wiki-news-300d-1M.v 100%[===================>] 650.22M  28.9MB/s    in 22s
#
# 2023-10-24 08:58:43 (29.6 MB/s) - ‘wiki-news-300d-1M.vec.zip’ saved [681808098/681808098]

# %%
# !mv wiki-news-300d-1M.vec.zip media/
# !unzip -f media/wiki-news-300d-1M.vec.zip

# %%
keep_words= [x.rstrip() for x in open("./media/words_to_keep")]
keep_words
# Out:
# --2023-10-11 22:43:29--  https://dl.fbaipublicfiles.com/fasttext/vectors-english/wiki-news-300d-1M.vec.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 2600:9000:20a6:e400:13:6e38:acc0:93a1, 2600:9000:20a6:e200:13:6e38:acc0:93a1, 2600:9000:20a6:a00:13:6e38:acc0:93a1, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|2600:9000:20a6:e400:13:6e38:acc0:93a1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 681808098 (650M) [application/zip]
# Saving to: ‘wiki-news-300d-1M.vec.zip’
#
# wiki-news-300d-1M.v 100%[===================>] 650.22M  27.2MB/s    in 25s
#
# 2023-10-11 22:43:55 (25.9 MB/s) - ‘wiki-news-300d-1M.vec.zip’ saved [681808098/681808098]
# ['Athens',
#  'Greece',
#  'Bangkok',
#  'Thailand',
#  'Latvia',
#  'lats',
#  'Bulgaria',
#  'lev',
#  'bad',
#  'worse',
#  'big',
#  'bigger',
#  'boy',
#  'girl',
#  'brother',
#  'sister']

# %%
import numpy as np
words_embeds = {}
for line in open("wiki-news-300d-1M.vec"):
    data = line.split()
    if data[0] in keep_words:
        words_embeds[data[0]] = np.array(list(map(float, data[1:])))

# %%
words_embeds["big"].size
# Out:
# 300

# %%
words_embeds.keys()
# Out:
# dict_keys(['big', 'bad', 'girl', 'Greece', 'boy', 'brother', 'worse', 'sister', 'bigger', 'Thailand', 'Bulgaria', 'Athens', 'Latvia', 'Bangkok', 'lats', 'lev'])

# %%
res = words_embeds["girl"] - words_embeds["boy"] + words_embeds["brother"]
res
# Out:
# array([ 0.3193, -0.0592, -0.0461, -0.1192, -0.0269,  0.0761, -0.0135,
#        -0.0527, -0.0506,  0.073 ,  0.0514, -0.1087,  0.0921, -0.0437,
#         0.0175,  0.204 , -0.0187, -0.0671,  0.1144, -0.0361, -0.1047,
#         0.1144, -0.2408,  0.0436,  0.0406, -0.0068, -0.1024,  0.1106,
#        -0.0419, -0.1826,  0.1547,  0.0084, -0.2653,  0.1108, -0.1934,
#         0.152 , -0.1   , -0.0516,  0.0547, -0.0557, -0.0244,  0.1113,
#        -0.0535,  0.0241,  0.0024, -0.0016, -0.0264,  0.0544,  0.0263,
#        -0.0619,  0.0101, -0.0284, -0.6605,  0.12  ,  0.051 , -0.0162,
#        -0.0769,  0.1983,  0.0784,  0.0058,  0.0147, -0.0124, -0.0843,
#        -0.076 , -0.0489, -0.0935, -0.0857,  0.113 ,  0.0732, -0.0112,
#         0.0516, -0.0555, -0.026 ,  0.0495, -0.0793,  0.1126,  0.0691,
#         0.1725, -0.0754,  0.049 ,  0.036 , -0.1203, -0.0533, -0.185 ,
#         0.108 , -0.073 , -0.2247, -0.2533,  0.1525,  0.0283, -0.0906,
#         0.1891,  0.0952, -0.0831,  0.1297,  0.1307, -0.0464,  0.0717,
#         0.0647, -0.0067, -0.2529,  0.0477, -0.0363,  0.1027, -0.0676,
#         0.1854,  0.1998,  0.0371, -0.3388,  0.1181,  0.0703,  0.1413,
#         0.0536,  0.0219, -0.0063, -0.1822, -0.3151, -0.1762, -0.1727,
#        -0.451 , -0.0104,  0.0166,  0.1902, -0.0361, -0.028 ,  0.263 ,
#         0.0306,  0.1736,  0.2473, -0.0301,  0.0036,  0.2979, -0.0866,
#         0.0542, -0.0219,  0.118 , -0.0455, -0.1473, -0.0924,  0.1029,
#         0.0844,  0.063 ,  0.1515,  0.212 ,  0.053 ,  0.0436,  0.0217,
#        -0.0409, -0.1192, -0.1309, -0.1141, -0.0074, -0.0096,  0.004 ,
#        -0.1566,  0.0187, -0.1142,  0.065 ,  0.0323, -0.0358,  0.0073,
#        -0.2284,  0.064 ,  0.1503,  0.0066,  0.1153,  0.1018,  0.1183,
#        -0.148 , -0.0377, -0.0398, -0.0993, -0.0892,  0.0649,  0.1157,
#        -0.0604,  0.2441, -0.1802,  0.1441,  0.0768, -0.1027, -0.0414,
#        -0.0212,  0.1544, -0.0651,  0.0129,  0.1929, -0.1133, -0.0481,
#         0.0746,  0.0185,  0.0486, -0.1424,  0.0473,  0.0012, -0.0509,
#        -0.0853,  0.0225,  0.1406,  0.0232, -0.0666, -0.1215, -0.1195,
#        -0.0482,  0.1838,  0.0149, -0.1235, -0.1072,  0.0065,  0.0344,
#        -0.0378,  0.0475, -0.047 , -0.0156, -0.0398, -0.1028, -0.0299,
#        -0.0596,  0.1034, -0.0347, -0.0509, -0.0429,  0.1024,  0.1888,
#         0.0467,  0.0797,  0.0307,  0.0037, -0.005 , -0.0884, -0.2874,
#         0.1423,  0.4253, -0.0449, -0.2076, -0.1025,  0.0101,  0.1853,
#        -0.3444, -0.0824, -0.0531, -0.0139,  0.038 , -0.0606, -0.003 ,
#        -0.1401,  0.1382, -0.0076, -0.0624,  0.3538,  0.1459,  0.1313,
#        -0.0751, -0.0563, -0.0091, -0.0223, -0.2093,  0.0916, -0.0427,
#        -0.0763, -0.0661,  0.0626,  0.0897, -0.1476, -0.4812, -0.0301,
#         0.1338,  0.1397, -0.0199,  0.0892,  0.0102,  0.0805, -0.0375,
#        -0.1161, -0.0057,  0.143 , -0.0438, -0.0931,  0.0229,  0.1268,
#        -0.1536, -0.1259, -0.0057,  0.0952,  0.0919,  0.1516, -0.0319,
#        -0.24  ,  0.1136,  0.1703, -0.0128,  0.0314,  0.0022,  0.0357,
#         0.1626, -0.0577, -0.0027, -0.0098,  0.05  , -0.1224])

# %%
(res - words_embeds["sister"]).round(2)
# Out:
# array([ 0.09,  0.03, -0.02, -0.01,  0.06,  0.  , -0.03, -0.1 , -0.18,
#         0.05,  0.08,  0.09,  0.15, -0.  , -0.02,  0.12, -0.15, -0.14,
#         0.08,  0.1 , -0.11,  0.09, -0.12, -0.12,  0.04,  0.05, -0.  ,
#        -0.  , -0.04, -0.11, -0.03, -0.03, -0.06,  0.02, -0.13,  0.05,
#        -0.13,  0.04, -0.01, -0.03,  0.11,  0.03,  0.07,  0.01,  0.1 ,
#         0.  ,  0.02,  0.06,  0.1 , -0.07,  0.02,  0.05, -0.02,  0.12,
#         0.07, -0.04, -0.01, -0.03,  0.01, -0.04,  0.03, -0.17,  0.02,
#         0.04, -0.16,  0.11, -0.03,  0.05, -0.06,  0.03, -0.05, -0.07,
#         0.03, -0.  , -0.08, -0.05,  0.06,  0.1 , -0.01,  0.08,  0.01,
#        -0.07,  0.02,  0.03,  0.08, -0.14, -0.11, -0.12,  0.03,  0.05,
#         0.02,  0.05,  0.03, -0.02,  0.08, -0.02, -0.06,  0.09,  0.07,
#         0.02, -0.  ,  0.1 , -0.  ,  0.06, -0.06, -0.09, -0.  , -0.08,
#        -0.04,  0.1 , -0.07,  0.08,  0.1 ,  0.02, -0.  , -0.03, -0.22,
#        -0.06, -0.05, -0.07,  0.04, -0.01,  0.06, -0.  ,  0.01,  0.04,
#        -0.01,  0.05,  0.04, -0.04, -0.05,  0.15, -0.05, -0.07, -0.02,
#         0.13,  0.04, -0.01,  0.03,  0.07,  0.03,  0.05,  0.09,  0.01,
#         0.03, -0.03, -0.04, -0.1 , -0.06, -0.09,  0.12, -0.04,  0.02,
#         0.02, -0.05,  0.02, -0.04, -0.06,  0.03,  0.02,  0.03, -0.08,
#         0.13,  0.08,  0.02,  0.07,  0.  ,  0.1 , -0.06, -0.11, -0.08,
#        -0.01, -0.02,  0.1 ,  0.  , -0.  ,  0.01, -0.03,  0.04,  0.08,
#        -0.06,  0.01, -0.03,  0.03, -0.05, -0.  , -0.07, -0.06, -0.13,
#        -0.04, -0.02, -0.07, -0.08,  0.02, -0.11,  0.06,  0.04, -0.07,
#         0.03,  0.07, -0.08, -0.05, -0.18, -0.01,  0.07, -0.03,  0.12,
#        -0.1 , -0.06,  0.05,  0.04,  0.06, -0.02, -0.04,  0.08, -0.1 ,
#         0.03,  0.01, -0.1 , -0.08, -0.02,  0.01,  0.05,  0.16,  0.09,
#         0.1 , -0.08,  0.01, -0.04,  0.02, -0.05,  0.04,  0.04, -0.03,
#        -0.14, -0.  ,  0.06, -0.02, -0.05,  0.1 , -0.1 ,  0.01,  0.02,
#         0.  , -0.02, -0.01,  0.05, -0.01,  0.01, -0.03, -0.05, -0.  ,
#        -0.01,  0.1 , -0.02,  0.01, -0.12,  0.06, -0.  ,  0.  , -0.03,
#         0.05, -0.09, -0.11, -0.24,  0.01,  0.05,  0.04,  0.06,  0.06,
#         0.04, -0.01, -0.03, -0.12, -0.04,  0.11,  0.01, -0.03, -0.06,
#         0.13, -0.1 ,  0.04,  0.03,  0.09,  0.13,  0.07,  0.07, -0.08,
#        -0.02,  0.06,  0.01, -0.14,  0.08,  0.03,  0.03, -0.03,  0.03,
#         0.01, -0.07,  0.  ])

# %%
words_embeds["big"] - words_embeds["bigger"]
# Out:
# array([-0.1327,  0.0784, -0.055 ,  0.0611,  0.0797,  0.1164,  0.046 ,
#        -0.037 , -0.0355,  0.0513, -0.0199, -0.0035, -0.0899, -0.1537,
#         0.1146, -0.0609, -0.0377,  0.0771,  0.1355, -0.0447,  0.0406,
#         0.0276, -0.0242, -0.1399, -0.015 , -0.017 ,  0.0434,  0.1223,
#        -0.1286, -0.0405, -0.0133,  0.0051,  0.148 , -0.0099, -0.0094,
#        -0.0259, -0.0225, -0.0012,  0.0467,  0.0649, -0.0056, -0.1069,
#        -0.0731, -0.0892,  0.0733, -0.147 , -0.0383, -0.021 , -0.0656,
#        -0.0414,  0.0473, -0.1991,  0.0511, -0.1198, -0.0425,  0.0225,
#         0.0601, -0.0004,  0.1398, -0.1176,  0.0966, -0.0023, -0.0718,
#        -0.1041, -0.0655,  0.0543, -0.0539, -0.0064,  0.014 , -0.0332,
#         0.0053, -0.005 ,  0.0586, -0.0089, -0.0059,  0.0169,  0.0279,
#         0.0184, -0.0467, -0.1185,  0.0281, -0.1469,  0.0144, -0.0349,
#        -0.029 , -0.0187,  0.0252,  0.0442,  0.0651, -0.029 , -0.0815,
#         0.0467, -0.067 ,  0.0571,  0.0345, -0.0431,  0.036 , -0.0751,
#         0.0092, -0.0862,  0.0389,  0.0342, -0.0658,  0.0239,  0.0905,
#         0.0289,  0.061 ,  0.0361,  0.2203, -0.0791, -0.0133, -0.1703,
#         0.0123, -0.0828, -0.0798,  0.0219, -0.0244,  0.0702,  0.0208,
#        -0.0464,  0.0115,  0.1861,  0.0253, -0.061 , -0.062 , -0.0317,
#        -0.0357, -0.1717,  0.0884,  0.0203, -0.2204,  0.0104, -0.1121,
#        -0.0707,  0.0403, -0.0053, -0.0635, -0.0236,  0.2271, -0.1433,
#         0.0159,  0.047 , -0.0564,  0.0294, -0.0453,  0.0174,  0.0115,
#         0.1021,  0.056 ,  0.0449,  0.054 , -0.1198, -0.0737,  0.0879,
#         0.0077, -0.0389, -0.081 ,  0.0016,  0.0128,  0.0446, -0.3555,
#        -0.0208,  0.0773,  0.0858,  0.0981,  0.0124, -0.0456, -0.0716,
#        -0.0302,  0.026 , -0.079 , -0.0192, -0.0301, -0.0464, -0.045 ,
#        -0.1567, -0.04  ,  0.111 ,  0.0522,  0.0672,  0.0056,  0.1485,
#        -0.0944, -0.0309,  0.0452, -0.0186, -0.0941,  0.0117,  0.0474,
#         0.1355, -0.044 ,  0.0219, -0.046 , -0.0041, -0.073 , -0.0906,
#        -0.1119,  0.0108, -0.0533,  0.0478,  0.1159, -0.0834,  0.087 ,
#         0.0611, -0.0648, -0.0423, -0.0183, -0.0042, -0.0193, -0.0726,
#        -0.1142,  0.0732,  0.0243,  0.1204,  0.0746, -0.0381, -0.0085,
#        -0.0638, -0.1633,  0.2374,  0.0199,  0.1293,  0.0976, -0.043 ,
#        -0.0626, -0.1019, -0.0404,  0.002 ,  0.0127, -0.134 ,  0.0528,
#        -0.0334,  0.0267, -0.0407,  0.0496, -0.0748, -0.0304, -0.1855,
#         0.0248, -0.0349,  0.0388,  0.0062,  0.013 ,  0.0604, -0.0165,
#         0.0734, -0.0835,  0.0108,  0.066 , -0.0274,  0.0203, -0.065 ,
#         0.0251, -0.0038,  0.151 ,  0.0324,  0.0595, -0.0361, -0.0372,
#         0.062 , -0.2015,  0.0479,  0.0984, -0.0091, -0.0253, -0.0207,
#        -0.1285, -0.062 , -0.1421,  0.0391, -0.0191,  0.0514, -0.0187,
#         0.0473,  0.0245, -0.0711,  0.1757,  0.0211,  0.0103, -0.0392,
#         0.0941, -0.0541, -0.0161, -0.1476,  0.0122,  0.0136, -0.0226,
#        -0.083 ,  0.0444, -0.1325,  0.0293, -0.0418,  0.0116, -0.0124,
#         0.0033,  0.0623,  0.042 ,  0.0038, -0.1803,  0.0187])

# %%
words_embeds["bad"] - words_embeds["worse"]
# Out:
# array([-0.0787,  0.0242, -0.1185, -0.0537,  0.043 , -0.0393,  0.0571,
#         0.0376, -0.0712,  0.0804, -0.0086, -0.0253, -0.0076, -0.0387,
#         0.0228, -0.0386, -0.1761,  0.1261, -0.1006, -0.0851, -0.0035,
#         0.0702,  0.0701, -0.032 , -0.1056, -0.0551, -0.0382,  0.0622,
#        -0.1478,  0.0503, -0.0453,  0.0566,  0.1311,  0.1304, -0.0086,
#        -0.0209, -0.1283,  0.0258, -0.0828,  0.1165,  0.031 ,  0.0346,
#        -0.166 , -0.0239, -0.0041,  0.0102,  0.1294, -0.0491,  0.0247,
#        -0.0963,  0.0205, -0.125 , -0.0094, -0.0271, -0.0095, -0.0034,
#         0.0866, -0.0041,  0.1393, -0.1289,  0.0528,  0.0063, -0.1536,
#        -0.0411,  0.0974,  0.2016, -0.0616,  0.0381,  0.0947, -0.0441,
#         0.0408,  0.0899, -0.0282,  0.0379,  0.0183,  0.0029,  0.0329,
#         0.0653,  0.1541, -0.0011,  0.0159, -0.0963,  0.1247, -0.0394,
#         0.0224,  0.0022, -0.0763, -0.0646,  0.2064,  0.1143, -0.0372,
#         0.0529,  0.0101,  0.0577,  0.0126,  0.0242,  0.0227,  0.0749,
#         0.0312, -0.0792,  0.0285,  0.1511, -0.0114,  0.0903,  0.1325,
#        -0.0421,  0.0679, -0.0051,  0.2073, -0.1845, -0.0771, -0.1836,
#         0.0812, -0.0139, -0.1975,  0.0519,  0.0068, -0.076 ,  0.064 ,
#         0.0063, -0.0734,  0.0403, -0.0104, -0.0515, -0.1401,  0.0055,
#         0.093 , -0.2951,  0.0726,  0.0164,  0.0499, -0.0477, -0.0683,
#         0.0032, -0.0602, -0.042 , -0.1132, -0.0168,  0.2775, -0.1709,
#        -0.0032, -0.0454, -0.0434, -0.0199,  0.0452, -0.0277,  0.0159,
#        -0.0986,  0.0472,  0.0632, -0.0819,  0.0343, -0.1633,  0.0206,
#         0.04  , -0.0046, -0.0618,  0.0409,  0.109 ,  0.0358, -0.2537,
#         0.0409,  0.0505,  0.0587,  0.1146,  0.0544,  0.0376,  0.0944,
#         0.0165,  0.1191,  0.0111, -0.103 , -0.1089, -0.0743, -0.0096,
#        -0.1116,  0.0353, -0.1328,  0.0597,  0.1278,  0.1087,  0.0231,
#        -0.0746, -0.0778,  0.1135,  0.1077, -0.0216,  0.0832,  0.022 ,
#         0.2293, -0.1069, -0.1115,  0.0277,  0.0691, -0.0045, -0.0706,
#        -0.1694,  0.141 , -0.1348,  0.0197,  0.0162, -0.1753,  0.0075,
#         0.0105, -0.1054, -0.1683, -0.1836,  0.0982, -0.0024, -0.02  ,
#         0.0074, -0.0549, -0.0164, -0.0602, -0.0357,  0.0935, -0.0466,
#        -0.0501, -0.2002,  0.2457,  0.0384,  0.1169, -0.0021, -0.0652,
#        -0.0565, -0.2604, -0.0939, -0.1365, -0.1276, -0.2031,  0.1792,
#        -0.002 , -0.0096, -0.019 , -0.0755, -0.2365,  0.0438, -0.1667,
#         0.0308, -0.0797,  0.0316, -0.0174, -0.0185,  0.0324, -0.0666,
#        -0.0292, -0.1039, -0.1239, -0.0534,  0.0345, -0.0717,  0.1057,
#         0.0362, -0.1335,  0.2186, -0.0198,  0.0295, -0.0524,  0.0072,
#        -0.0003, -0.071 ,  0.1764,  0.0664,  0.0249, -0.0277,  0.0019,
#        -0.1679, -0.0854, -0.1193,  0.0288, -0.0091,  0.0414, -0.0466,
#         0.0515,  0.0042, -0.0298,  0.1657, -0.0594,  0.0269, -0.014 ,
#        -0.0105, -0.1407, -0.0398,  0.0062, -0.0083, -0.0175,  0.1885,
#        -0.0486,  0.1707, -0.0904,  0.0326, -0.0808,  0.0444,  0.1051,
#         0.0035,  0.1401,  0.0054,  0.006 , -0.259 , -0.0478])

# %%
(words_embeds["bad"] - words_embeds["worse"]) - (words_embeds["big"] - words_embeds["bigger"])
# Out:
# array([ 5.400e-02, -5.420e-02, -6.350e-02, -1.148e-01, -3.670e-02,
#        -1.557e-01,  1.110e-02,  7.460e-02, -3.570e-02,  2.910e-02,
#         1.130e-02, -2.180e-02,  8.230e-02,  1.150e-01, -9.180e-02,
#         2.230e-02, -1.384e-01,  4.900e-02, -2.361e-01, -4.040e-02,
#        -4.410e-02,  4.260e-02,  9.430e-02,  1.079e-01, -9.060e-02,
#        -3.810e-02, -8.160e-02, -6.010e-02, -1.920e-02,  9.080e-02,
#        -3.200e-02,  5.150e-02, -1.690e-02,  1.403e-01,  8.000e-04,
#         5.000e-03, -1.058e-01,  2.700e-02, -1.295e-01,  5.160e-02,
#         3.660e-02,  1.415e-01, -9.290e-02,  6.530e-02, -7.740e-02,
#         1.572e-01,  1.677e-01, -2.810e-02,  9.030e-02, -5.490e-02,
#        -2.680e-02,  7.410e-02, -6.050e-02,  9.270e-02,  3.300e-02,
#        -2.590e-02,  2.650e-02, -3.700e-03, -5.000e-04, -1.130e-02,
#        -4.380e-02,  8.600e-03, -8.180e-02,  6.300e-02,  1.629e-01,
#         1.473e-01, -7.700e-03,  4.450e-02,  8.070e-02, -1.090e-02,
#         3.550e-02,  9.490e-02, -8.680e-02,  4.680e-02,  2.420e-02,
#        -1.400e-02,  5.000e-03,  4.690e-02,  2.008e-01,  1.174e-01,
#        -1.220e-02,  5.060e-02,  1.103e-01, -4.500e-03,  5.140e-02,
#         2.090e-02, -1.015e-01, -1.088e-01,  1.413e-01,  1.433e-01,
#         4.430e-02,  6.200e-03,  7.710e-02,  6.000e-04, -2.190e-02,
#         6.730e-02, -1.330e-02,  1.500e-01,  2.200e-02,  7.000e-03,
#        -1.040e-02,  1.169e-01,  5.440e-02,  6.640e-02,  4.200e-02,
#        -7.100e-02,  6.900e-03, -4.120e-02, -1.300e-02, -1.054e-01,
#        -6.380e-02, -1.330e-02,  6.890e-02,  6.890e-02, -1.177e-01,
#         3.000e-02,  3.120e-02, -1.462e-01,  4.320e-02,  5.270e-02,
#        -8.490e-02, -1.458e-01, -3.570e-02,  9.500e-03, -7.810e-02,
#         3.720e-02,  1.287e-01, -1.234e-01, -1.580e-02, -3.900e-03,
#         2.703e-01, -5.810e-02,  4.380e-02,  7.390e-02, -1.005e-01,
#        -3.670e-02, -4.970e-02,  6.800e-03,  5.040e-02, -2.760e-02,
#        -1.910e-02, -9.240e-02,  1.300e-02, -4.930e-02,  9.050e-02,
#        -4.510e-02,  4.400e-03, -2.007e-01, -8.800e-03,  1.830e-02,
#        -1.359e-01,  1.541e-01, -8.960e-02, -6.730e-02,  3.230e-02,
#         3.430e-02,  1.920e-02,  3.930e-02,  9.620e-02, -8.800e-03,
#         1.018e-01,  6.170e-02, -2.680e-02, -2.710e-02,  1.650e-02,
#         4.200e-02,  8.320e-02,  1.660e-01,  4.670e-02,  9.310e-02,
#         9.010e-02, -8.380e-02, -7.880e-02, -2.790e-02,  3.540e-02,
#         4.510e-02,  7.530e-02, -2.438e-01,  7.500e-03,  6.060e-02,
#         1.031e-01, -1.254e-01,  1.980e-02, -4.690e-02,  6.830e-02,
#         1.263e-01,  7.250e-02,  7.150e-02, -2.540e-02,  9.380e-02,
#        -6.290e-02, -1.334e-01,  7.370e-02,  7.320e-02,  6.850e-02,
#         2.000e-02, -5.750e-02,  1.302e-01, -8.150e-02, -2.810e-02,
#        -9.970e-02, -9.190e-02, -7.950e-02, -5.060e-02, -4.060e-02,
#        -1.260e-01, -1.653e-01,  1.024e-01,  1.690e-02,  5.260e-02,
#         1.216e-01, -1.281e-01, -4.070e-02, -1.806e-01, -1.103e-01,
#         1.316e-01, -3.810e-02,  1.370e-02, -3.690e-02,  8.300e-03,
#         1.850e-02, -1.240e-02, -9.970e-02, -2.220e-02,  6.100e-03,
#        -1.585e-01, -5.350e-02, -1.385e-01, -1.403e-01, -6.910e-02,
#         1.264e-01,  3.140e-02, -3.630e-02,  2.170e-02, -1.251e-01,
#        -1.617e-01,  7.420e-02,  1.880e-02,  6.000e-03, -4.480e-02,
#        -7.200e-03, -2.360e-02, -3.150e-02, -2.800e-02, -5.010e-02,
#        -1.026e-01, -2.040e-02, -1.347e-01, -1.194e-01,  6.190e-02,
#        -9.200e-02,  1.707e-01,  1.110e-02, -1.297e-01,  6.760e-02,
#        -5.220e-02, -3.000e-02, -1.630e-02,  4.440e-02, -6.230e-02,
#         1.305e-01,  1.285e-01, -3.200e-02,  3.400e-02, -2.400e-03,
#         2.260e-02, -3.940e-02, -2.340e-02,  2.280e-02, -1.030e-02,
#         1.000e-02, -1.000e-02, -2.790e-02,  4.200e-03, -2.030e-02,
#         4.130e-02, -1.000e-02, -8.050e-02,  1.660e-02,  2.520e-02,
#        -1.046e-01, -8.660e-02, -2.370e-02,  1.538e-01, -2.050e-02,
#        -3.110e-02,  2.111e-01,  3.440e-02,  1.263e-01,  4.210e-02,
#         3.300e-03, -3.900e-02,  3.280e-02,  1.175e-01,  2.000e-04,
#         7.780e-02, -3.660e-02,  2.200e-03, -7.870e-02, -6.650e-02])

# %%
# https://github.com/facebookresearch/faiss
# !pip install faiss

# %%
import faiss

# %%
words = np.array(list(words_embeds.keys()))
embeds = np.array(list(words_embeds.values()))

# %%
index = faiss.IndexFlatL2(300)
index.add(embeds)

# %%
np.array([words_embeds["bad"]])
# Out:
# array([[ 3.180e-02, -1.105e-01, -1.446e-01, -3.510e-02, -4.610e-02,
#          6.990e-02,  4.390e-02, -4.310e-02,  7.330e-02, -6.790e-02,
#          7.900e-03, -1.142e-01, -3.660e-02, -3.880e-02, -8.730e-02,
#          1.160e-02, -1.213e-01,  7.770e-02,  1.200e-03, -9.450e-02,
#          8.100e-03,  7.300e-03,  4.880e-02,  1.211e-01, -2.710e-02,
#         -1.052e-01, -4.690e-02, -6.370e-02, -4.960e-02, -1.770e-02,
#          4.860e-02, -3.890e-02,  2.301e-01,  1.047e-01,  8.890e-02,
#          1.141e-01, -2.470e-02, -5.620e-02, -6.120e-02,  9.820e-02,
#          1.081e-01,  6.760e-02, -1.718e-01, -1.690e-02, -1.780e-02,
#         -6.100e-03,  3.450e-02,  8.070e-02,  1.600e-02,  2.320e-02,
#          4.800e-02, -9.170e-02, -7.630e-01, -4.980e-02,  3.170e-02,
#         -3.420e-02,  1.029e-01,  2.180e-02,  6.800e-03, -5.440e-02,
#         -1.476e-01, -2.400e-03,  3.340e-02, -5.610e-02,  1.173e-01,
#         -1.176e-01,  2.580e-02,  9.420e-02, -5.800e-02,  1.440e-02,
#         -2.730e-02,  5.440e-02, -6.590e-02, -8.370e-02,  5.880e-02,
#          2.010e-02,  2.260e-01, -5.320e-02,  1.632e-01,  1.736e-01,
#         -5.200e-03,  5.720e-02,  4.590e-02, -2.270e-01, -4.280e-02,
#         -6.900e-02, -3.890e-02, -1.825e-01,  8.290e-02,  7.570e-02,
#          1.640e-02,  1.291e-01, -1.293e-01, -8.890e-02, -4.020e-02,
#          2.015e-01,  2.340e-02,  1.723e-01,  6.180e-02,  3.010e-02,
#         -1.490e-01,  2.002e-01,  9.610e-02,  6.280e-02,  3.110e-02,
#         -5.740e-02,  2.817e-01,  3.930e-02,  3.550e-02,  2.600e-03,
#         -7.670e-02, -3.230e-02, -8.400e-03, -5.810e-02, -1.306e-01,
#         -5.150e-02, -3.410e-02,  2.870e-02,  2.350e-02, -2.967e-01,
#         -1.443e-01,  8.770e-02, -1.761e-01,  2.520e-02, -2.300e-02,
#          1.878e-01, -1.730e-02, -8.380e-02, -7.640e-02,  1.619e-01,
#          1.408e-01, -1.177e-01, -1.117e-01,  3.280e-02, -1.147e-01,
#         -3.743e-01, -5.180e-02,  3.260e-02,  2.254e-01, -9.010e-02,
#          3.940e-02,  4.540e-02, -4.970e-02,  2.476e-01,  4.660e-02,
#         -1.683e-01,  8.530e-02, -8.300e-02, -6.060e-02,  1.310e-01,
#          4.660e-02,  3.810e-02, -4.880e-02,  7.580e-02,  1.207e-01,
#          1.063e-01, -6.220e-02,  1.130e-01,  2.430e-02, -4.270e-02,
#         -2.125e-01,  7.220e-02,  6.170e-02,  5.110e-02,  2.861e-01,
#         -9.000e-04,  1.378e-01, -2.041e-01,  7.740e-02,  1.320e-02,
#          1.538e-01, -1.280e-02, -1.423e-01, -6.800e-03,  7.870e-02,
#          5.640e-02,  2.336e-01,  1.158e-01, -3.550e-02,  7.750e-02,
#          1.282e-01,  1.467e-01, -1.595e-01, -1.030e-01, -3.310e-02,
#          1.245e-01, -9.350e-02, -1.444e-01,  1.075e-01,  6.060e-02,
#         -5.590e-02,  6.800e-03,  9.460e-02, -4.400e-02,  1.090e-01,
#          6.690e-02, -1.593e-01,  4.200e-02,  1.348e-01,  3.530e-02,
#         -1.340e-02, -1.932e-01, -6.390e-02,  3.060e-02,  1.084e-01,
#         -1.180e-02, -8.750e-02,  7.480e-02,  7.050e-02,  5.360e-02,
#          1.043e-01,  1.300e-03, -7.340e-02, -1.549e-01, -6.990e-02,
#          1.086e-01, -1.342e-01, -5.560e-02, -3.560e-02, -4.260e-02,
#          1.625e-01, -1.137e-01, -6.400e-03, -1.178e-01,  7.800e-03,
#         -2.980e-01, -1.092e-01, -6.820e-02, -1.520e-02, -2.102e-01,
#          1.200e-02, -7.480e-02,  2.661e-01,  3.620e-02,  9.400e-03,
#         -2.090e-02, -6.100e-02, -2.538e-01, -1.619e-01, -1.240e-02,
#         -2.900e-03,  4.460e-02, -7.580e-02,  7.210e-02, -5.100e-02,
#         -7.600e-02, -4.000e-04, -2.990e-02,  2.420e-02,  3.306e-01,
#          3.440e-02,  8.960e-02,  4.230e-02,  1.400e-02,  2.028e-01,
#         -6.300e-02, -9.440e-02,  4.770e-02, -9.400e-03, -5.430e-02,
#          5.280e-02,  8.150e-02,  3.050e-02,  1.120e-02,  7.910e-02,
#         -3.140e-02,  9.280e-02, -1.607e-01, -1.662e-01,  1.331e-01,
#          1.406e-01,  2.110e-02,  5.300e-03, -1.840e-02, -9.900e-03,
#          2.630e-02,  4.630e-02, -1.377e-01, -4.820e-02,  9.350e-02,
#         -2.130e-02, -3.510e-02, -4.350e-02, -1.505e-01,  2.750e-02,
#          1.757e-01,  1.457e-01, -7.300e-02,  5.110e-02, -1.990e-02,
#          3.760e-02,  1.400e-02,  1.200e-02,  4.990e-02,  1.125e-01,
#         -1.610e-01,  2.910e-02,  2.310e-01, -7.490e-02, -4.870e-02]])

# %%
index.search(np.array([words_embeds["bad"]]), k=3)
# Out:
# (array([[0.       , 2.598906 , 3.0293205]], dtype=float32), array([[1, 6, 0]]))

# %%
words
# Out:
# array(dict_keys(['big', 'bad', 'girl', 'Greece', 'boy', 'brother', 'worse', 'sister', 'bigger', 'Thailand', 'Bulgaria', 'Athens', 'Latvia', 'Bangkok', 'lats', 'lev']),
#       dtype=object)

# %%
words[0]

# %%
index.is_trained

# %% [markdown]
# ### Demo from Faiss: The Missing Manual
# - Demo posted on Pinecone's website
#
#   - [Faiss: The Missing Manual](https://www.pinecone.io/learn/series/faiss/faiss-tutorial/)
